# %%
#input_file = 'mgoresults.txt'  # Replace with the path to your large data file in .txt format
#output_file = 'new_data.txt'  # Replace with the desired file path and name for the new data file

# %%
import pandas as pd
data = pd.read_csv('mgoresults.csv',  delim_whitespace=True) 
# Replace 'data.txt' with the path to your .txt file
data.head()
# Out:
#     setMFX2I01   setMFX1I03   setMFX0I01   setMFA0I03  setMFD0I04  \
# 0  2215.238830  2490.168048  1697.485756  1473.030786    2.537046
# 1  2185.359869  2518.957964  1675.905318  1440.990757    2.533038
# 2  2199.015005  2474.844626  1753.904597  1456.670791    2.563057
# 3  2165.687643  2488.146144  1638.508108  1459.215023    2.559686
# 4  2225.578494  2449.229969  1725.321464  1374.681384    2.594334
#
#    setMFX1dsch2  setMFX2dsch2  setMFX3dsch2  setMQS0L01  setMQJ0L01  ...  \
# 0   2017.056884    234.360462  -1789.319949    8.538248  -97.152055  ...
# 1   1951.116265   -195.652766  -1803.226694   -2.025642  -86.449055  ...
# 2   1970.830949   -285.409182  -1801.399507   16.501729  -87.556565  ...
# 3   1950.624308   -456.398438  -1833.970525   -5.897058  -80.995307  ...
# 4   1904.012831   -552.053450  -1788.709457   -1.868129  -68.980143  ...
#
#    uf:CSalphay  uf:CSbetax  uf:CSbetay  ms:transmission  dv:transmission  \
# 0    49.838675   10.242943   37.074593            0.992            0.992
# 1    30.605703   17.366922   16.258708            0.992            0.992
# 2     9.003814   38.306757    0.825355            0.992            0.992
# 3    58.271807    8.444592   44.399540            0.992            0.992
# 4    22.958751    7.864654   44.392868            0.992            0.992
#
#    l2:transmission  l3:transmission  mgorank  mgoviolations  mgotasknumber
# 0            0.992            0.992      1.0            8.0        12595.0
# 1            0.992            0.992      0.0            8.0        12585.0
# 2            0.992            0.992      0.0            8.0        12564.0
# 3            0.992            0.992      0.0            8.0        12549.0
# 4            0.992            0.992      1.0            8.0        12526.0
#
# [5 rows x 93 columns]

# %%
#df = pd.read_csv(mgoresults.txt, delim_whitespace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/t7/yy62typn4y1cknks8l305k2h0000gn/T/ipykernel_74572/3097699217.py in <module>
# ----> 1 df = pd.read_csv(mgoresults.txt, delim_whitespace=True)
#
# NameError: name 'mgoresults' is not defined

# %%
data.columns
# Out:
# Index(['setMFX2I01', 'setMFX1I03', 'setMFX0I01', 'setMFA0I03', 'setMFD0I04',
#        'setMFX1dsch2', 'setMFX2dsch2', 'setMFX3dsch2', 'setMQS0L01',
#        'setMQJ0L01', 'setMQS0L01A', 'setMQJ0L02', 'setMQS0L02', 'setMQJ0L02A',
#        'setMQS0L02B', 'setMQJ0L03A', 'setMQS0L03', 'setMQJ0L03', 'setMQS0L04',
#        'setMQJ0L04', 'PREBUNCHERphase', 'BUNCHERphase', 'booster07phase',
#        'booster08phase', 'PREBUNCHERset', 'buncherset', 'booster07set',
#        'booster08set', 'uf:nemixrms', 'uf:nemiyrms', 'uf:stdt',
#        'dg:transmission', 's1:transmission', 's2:transmission',
#        'up:transmission', 'dp:transmission', 'up:stdx', 'up:stdy', 'dp:stdx',
#        'dp:stdy', 'up:avgEk_eV', 'dp:avgEk_eV', 'up:stdt', 'dp:stdt',
#        'ms:stdt', 'ub:transmission', 'db:transmission', 'ub:stdx', 'ub:stdy',
#        'db:stdx', 'db:stdy', 'ub:avgEk_eV', 'db:avgEk_eV', 'ub:stdt',
#        'db:stdt', 'uq:transmission', 'dq:transmission', 'uq:stdx', 'uq:stdy',
#        'dq:stdx', 'dq:stdy', 'uq:stdt', 'dq:stdt', 'uq:avgEk_eV',
#        'bq:avgEk_eV', 'dq:avgEk_eV', 'dq:avgx', 'dq:avgy', 'dq:avgr',
#        'uq:CSalphax', 'uq:CSalphay', 'uq:CSbetax', 'uq:CSbetay', 'dq:CSalphax',
#        'dq:CSalphay', 'dq:CSbetax', 'dq:CSbetay', 'uf:transmission', 'uf:stdx',
#        'uf:stdy', 'uf:avgEk_eV', 'uf:stdEk_eV', 'uf:CSalphax', 'uf:CSalphay',
#        'uf:CSbetax', 'uf:CSbetay', 'ms:transmission', 'dv:transmission',
#        'l2:transmission', 'l3:transmission', 'mgorank', 'mgoviolations',
#        'mgotasknumber'],
#       dtype='object')

# %%
data.describe()
# Out:
#         setMFX2I01   setMFX1I03   setMFX0I01   setMFA0I03  setMFD0I04  \
# count   120.000000   120.000000   120.000000   120.000000  120.000000
# mean   2194.698381  2472.096709  1647.314657  1411.897320    2.553292
# std      28.022893    16.530617    49.733984    29.991347    0.018466
# min    2125.953517  2438.466130  1495.258161  1351.250457    2.493148
# 25%    2182.020479  2462.032556  1617.192846  1387.412379    2.541736
# 50%    2194.162406  2470.332652  1648.073318  1409.399209    2.552664
# 75%    2209.454804  2481.818774  1686.723804  1429.766276    2.563158
# max    2301.883054  2530.100801  1753.904597  1498.344422    2.605997
#
#        setMFX1dsch2  setMFX2dsch2  setMFX3dsch2  setMQS0L01  setMQJ0L01  ...  \
# count    120.000000    120.000000    120.000000  120.000000  120.000000  ...
# mean    1941.737253   -412.496797  -1799.628574  -10.761791  -81.600040  ...
# std       39.829631    184.806498     14.493491   18.089595    7.876299  ...
# min     1817.836546   -836.979427  -1833.970525  -71.290211 -103.577171  ...
# 25%     1920.048160   -537.435732  -1810.027929  -21.714094  -86.370263  ...
# 50%     1943.378959   -431.270957  -1799.367524  -10.121338  -81.135757  ...
# 75%     1961.967270   -297.766634  -1789.883157   -1.554433  -76.410409  ...
# max     2032.277061    234.360462  -1770.702959   34.192295  -64.513376  ...
#
#        uf:CSalphay  uf:CSbetax  uf:CSbetay  ms:transmission  dv:transmission  \
# count   120.000000  120.000000  120.000000     1.200000e+02     1.200000e+02
# mean     27.057974   21.752573   17.664217     9.920000e-01     9.920000e-01
# std      18.356239   12.074515   20.323501     1.449341e-15     1.449341e-15
# min     -20.799214    3.269395    0.012891     9.920000e-01     9.920000e-01
# 25%      15.280328   13.487859    2.209482     9.920000e-01     9.920000e-01
# 50%      26.263026   19.219053    9.337709     9.920000e-01     9.920000e-01
# 75%      38.854684   27.412580   27.094234     9.920000e-01     9.920000e-01
# max      68.731880   74.917740   85.608471     9.920000e-01     9.920000e-01
#
#        l2:transmission  l3:transmission     mgorank  mgoviolations  \
# count       120.000000       120.000000  120.000000          120.0
# mean          0.991700         0.991700    0.641667            8.0
# std           0.002441         0.002441    0.515244            0.0
# min           0.968000         0.968000    0.000000            8.0
# 25%           0.992000         0.992000    0.000000            8.0
# 50%           0.992000         0.992000    1.000000            8.0
# 75%           0.992000         0.992000    1.000000            8.0
# max           0.992000         0.992000    2.000000            8.0
#
#        mgotasknumber
# count     120.000000
# mean    10300.233333
# std      1978.894007
# min      3596.000000
# 25%      8957.000000
# 50%     10866.500000
# 75%     11920.250000
# max     12595.000000
#
# [8 rows x 93 columns]

# %%
data[118:124]
# Out:
#      setMFX2I01  setMFX1I03  setMFX0I01  setMFA0I03  setMFD0I04  setMFX1dsch2  \
# 118  2211.31072  2477.03136  1625.83584     1426.80    2.562402    1924.79584
# 119  2195.36000  2454.68000  1554.40800     1398.76    2.560280    1926.44000
#
#      setMFX2dsch2  setMFX3dsch2  setMQS0L01  setMQJ0L01  ...  uf:CSalphay  \
# 118    -648.84405   -1798.18304   -7.373464     -77.472  ...    15.291065
# 119    -455.00800   -1770.72000   -2.938229     -82.930  ...     8.182811
#
#      uf:CSbetax  uf:CSbetay  ms:transmission  dv:transmission  \
# 118   18.252533    1.882155            0.992            0.992
# 119   43.817049    0.550880            0.992            0.992
#
#      l2:transmission  l3:transmission  mgorank  mgoviolations  mgotasknumber
# 118            0.992            0.992      0.0            8.0         5146.0
# 119            0.992            0.992      0.0            8.0         3596.0
#
# [2 rows x 93 columns]

# %%
data.columns
# Out:
# Index(['setMFX2I01', 'setMFX1I03', 'setMFX0I01', 'setMFA0I03', 'setMFD0I04',
#        'setMFX1dsch2', 'setMFX2dsch2', 'setMFX3dsch2', 'setMQS0L01',
#        'setMQJ0L01', 'setMQS0L01A', 'setMQJ0L02', 'setMQS0L02', 'setMQJ0L02A',
#        'setMQS0L02B', 'setMQJ0L03A', 'setMQS0L03', 'setMQJ0L03', 'setMQS0L04',
#        'setMQJ0L04', 'PREBUNCHERphase', 'BUNCHERphase', 'booster07phase',
#        'booster08phase', 'PREBUNCHERset', 'buncherset', 'booster07set',
#        'booster08set', 'uf:nemixrms', 'uf:nemiyrms', 'uf:stdt',
#        'dg:transmission', 's1:transmission', 's2:transmission',
#        'up:transmission', 'dp:transmission', 'up:stdx', 'up:stdy', 'dp:stdx',
#        'dp:stdy', 'up:avgEk_eV', 'dp:avgEk_eV', 'up:stdt', 'dp:stdt',
#        'ms:stdt', 'ub:transmission', 'db:transmission', 'ub:stdx', 'ub:stdy',
#        'db:stdx', 'db:stdy', 'ub:avgEk_eV', 'db:avgEk_eV', 'ub:stdt',
#        'db:stdt', 'uq:transmission', 'dq:transmission', 'uq:stdx', 'uq:stdy',
#        'dq:stdx', 'dq:stdy', 'uq:stdt', 'dq:stdt', 'uq:avgEk_eV',
#        'bq:avgEk_eV', 'dq:avgEk_eV', 'dq:avgx', 'dq:avgy', 'dq:avgr',
#        'uq:CSalphax', 'uq:CSalphay', 'uq:CSbetax', 'uq:CSbetay', 'dq:CSalphax',
#        'dq:CSalphay', 'dq:CSbetax', 'dq:CSbetay', 'uf:transmission', 'uf:stdx',
#        'uf:stdy', 'uf:avgEk_eV', 'uf:stdEk_eV', 'uf:CSalphax', 'uf:CSalphay',
#        'uf:CSbetax', 'uf:CSbetay', 'ms:transmission', 'dv:transmission',
#        'l2:transmission', 'l3:transmission', 'mgorank', 'mgoviolations',
#        'mgotasknumber'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data into a DataFrame
#data = pd.read_csv('data.csv')  # Replace 'data.csv' with the path to your data file

# Plot two columns
nemix = data['uf:nemixrms']  # Replace 'column1' with the name of the first column
nemiy = data['uf:nemiyrms']# Replace 'column2' with the name of the second column
stdt = data ['uf:stdt']
stdx = data['uf:stdx']
stdy = data['uf:stdy']
stdek =data['uf:stdEk_eV']           
plt.plot(stdx, stdt)
plt.xlabel('std(x)[m]')
plt.ylabel('std(t) [s]')
plt.title('Plot of std(x)  vs std(t)')
plt.show()

# %%
import matplotlib.pyplot as plt
# Plot the data points
plt.scatter(stdx, stdt, color='blue', label='Data Points')

# Identify the Pareto front
pareto_front = []
for i in range(len(stdx)):
    is_pareto = True
    for j in range(len(stdx)):
        if stdx[j] >= stdx[i] and stdt[j] >= stdt[i] and j != i:
            is_pareto = False
            break
    if is_pareto:
        pareto_front.append((stdx[i], stdt[i]))

# Extract the x and y values for the Pareto front
pareto_x = [point[0] for point in pareto_front]
pareto_y = [point[1] for point in pareto_front]

# Plot the Pareto front
plt.plot(pareto_x, pareto_y, color='red', label='Pareto Front')

# Set labels and title for the plot
plt.xlabel('stdx')
plt.ylabel('stdt')
plt.title('Pareto Front')

# Add legend
plt.legend()

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data into a DataFrame
#data = pd.read_csv('data.csv')  # Replace 'data.csv' with the path to your data file

# Extract the variables for Pareto front
#x_values = data['x']  # Replace 'x' with the name of the variable for x-axis
#y_values = data['y']  # Replace 'y' with the name of the variable for y-axis

# Plot the data points
plt.scatter(stdek, nemix, color='blue', label='Data Points')

# Identify the Pareto front
pareto_front = []
for i in range(len(stdek)):
    is_pareto = True
    for j in range(len(stdek)):
        if stdek[j] >= stdek[i] and nemix[j] >= nemix[i] and j != i:
            is_pareto = False
            break
    if is_pareto:
        pareto_front.append((stdek[i], nemix[i]))

# Extract the x and y values for the Pareto front
pareto_x = [point[0] for point in pareto_front]
pareto_y = [point[1] for point in pareto_front]

# Plot the Pareto front
plt.plot(pareto_x, pareto_y, color='red', label='Pareto Front')

# Set labels and title for the plot
plt.xlabel('stdEk')
plt.ylabel('nemix')
plt.title('Pareto Front')

# Add legend
plt.legend()

# Display the plot
plt.show()

# %%
# Sort the data frame by one of the columns in descending order
df = data.sort_values(by='uf:stdt', ascending=False)

# Create an empty list to store the Pareto front
pareto_front = []

# Iterate through the sorted data frame, adding each row to the Pareto front if it is not dominated by any of the previous rows in the front
for index, row in df.iterrows():
    if not any((row['uf:stdt'] < x['uf:stdt']) and (row['uf:stdx'] < x['uf:stdx']) for x in pareto_front):
        pareto_front.append(row)

# Convert the Pareto front to a data frame
pareto_df = pd.DataFrame(pareto_front)

# Plot the Pareto front using a scatter plot
plt.scatter(stdt, stdx, color='blue', label='Data Points')
plt.plot(pareto_df['uf:stdt'], pareto_df['uf:stdx'])
plt.xlabel('stdt')
plt.ylabel('stdx')
plt.show()

# %%
len(data.columns)
# Out:
# 1

# %%
import numpy as np

# Read data from the .txt file
#data = np.loadtxt('mgoresults.txt')

# Extract variables and objective values
variables = data['setMFX2I01']  # Columns representing variables (x1, x2, ...)
objectives = data['setMFX1I03']  # Columns representing objective values (y1, y2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/ee/lib/python3.11/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/anaconda3/envs/ee/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/anaconda3/envs/ee/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'setMFX2I01'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 7
#       1 import numpy as np
#       3 # Read data from the .txt file
#       4 #data = np.loadtxt('mgoresults.txt')
#       5
#       6 # Extract variables and objective values
# ----> 7 variables = data['setMFX2I01']  # Columns representing variables (x1, x2, ...)
#       8 objectives = data['setMFX1I03']  # Columns representing objective values (y1, y2)
#
# File /opt/anaconda3/envs/ee/lib/python3.11/site-packages/pandas/core/frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File /opt/anaconda3/envs/ee/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'setMFX2I01'

# %%
# Calculate the Pareto front
pareto_front_indices = []
for i in range(len(objectives)):
    is_pareto = True
    for j in range(len(objectives)):
        if all(objectives[j] < objectives[i]) and any(objectives[j] != objectives[i]):
            is_pareto = False
            break
    if is_pareto:
        pareto_front_indices.append(i)

pareto_front = variables[pareto_front_indices]

# %%
input_file = 'mgoresults.txt'  # Replace with the path to your large data file in .txt format
output_file = 'new_data.txt'  # Replace with the desired file path and name for the new data file

# Select the desired columns from the large dataset
selected_columns = [2, 3, 4]  # Replace with the indices of the columns you want to select (starting from 0)

# Read the large data file and extract the selected columns
with open(input_file, 'r') as file:
    lines = file.readlines()

selected_data = []
for line in lines:
    values = line.strip().split()
    selected_values = [values[col_index] for col_index in selected_columns]
    selected_data.append(selected_values)

# Save the selected data to a new file
with open(output_file, 'w') as file:
    for selected_values in selected_data:
        line = '\t'.join(selected_values) + '\n'  # Assuming tab-separated values, modify the delimiter if needed
        file.write(line)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 14
#      12 for line in lines:
#      13     values = line.strip().split()
# ---> 14     selected_values = [values[col_index] for col_index in selected_columns]
#      15     selected_data.append(selected_values)
#      17 # Save the selected data to a new file
#
# Cell In[9], line 14, in <listcomp>(.0)
#      12 for line in lines:
#      13     values = line.strip().split()
# ---> 14     selected_values = [values[col_index] for col_index in selected_columns]
#      15     selected_data.append(selected_values)
#      17 # Save the selected data to a new file
#
# IndexError: list index out of range
