# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense

# Create a neural network model
model = tf.keras.Sequential([
    Dense(40, activation='tanh', input_shape=(28,)),
    Dense(40, activation='tanh'),
    Dense(40, activation='tanh'),
    Dense(40, activation='tanh'),
    Dense(7)  # Output layer with 7 nodes for objectives
])

# Visualize the neural network architecture
tf.keras.utils.plot_model(model, to_file='neural_network.png', show_shapes=True, show_layer_names=True)

# Show the plot
img = plt.imread('neural_network.png')
plt.savefig('neural_network.png')
plt.figure(figsize=(8, 8))
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense

# Create a neural network model
model = tf.keras.Sequential([
    Dense(40, activation='tanh', input_shape=(28,)),
    Dense(40, activation='tanh'),
    Dense(40, activation='tanh'),
    Dense(40, activation='tanh'),
    Dense(7)  # Output layer with 7 nodes for objectives
])

# Visualize the neural network architecture with custom appearance
plot_model = tf.keras.utils.plot_model(
    model,
    to_file='neural_network.png',
    show_shapes=True,
    show_layer_names=True,
    dpi=96  # Set the DPI for better quality
)

# Show the plot with custom fonts and colors
img = plt.imread('neural_network.png')
plt.figure(figsize=(10, 10))  # Increase the figure size
plt.imshow(img)
plt.axis('off')

# Customize fonts and colors (you can adjust these as needed)
plt.rcParams.update({
    'text.color': 'white',  # Font color
    'font.size': 14,        # Font size
    'axes.labelcolor': 'white',
    'axes.edgecolor': 'white',
    'xtick.color': 'white',
    'ytick.color': 'white',
    'axes.facecolor': '#3c3c3c',  # Background color
    'figure.facecolor': '#3c3c3c'  # Figure background color
})

plt.show()

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Define a large neural network model
class LargeModel(nn.Module):
    def __init__(self):
        super(LargeModel, self).__init__()
        self.layer1 = nn.Linear(1000, 512)
        self.layer2 = nn.Linear(512, 256)
        self.layer3 = nn.Linear(256, 10)
    
    def forward(self, x):
        x = self.layer1(x)
        x = self.layer2(x)
        x = self.layer3(x)
        return x

# Create instances of the model for different GPUs
device1 = torch.device("cuda:0")
device2 = torch.device("cuda:1")

model_gpu1 = LargeModel().to(device1)
model_gpu2 = LargeModel().to(device2)

# Define a dummy data batch
input_data = torch.randn(64, 1000).to(device1)

# Split the forward pass across GPUs
output1 = model_gpu1(input_data)
output2 = model_gpu2(output1)  # Output from GPU1 passed to GPU2

# Calculate loss, backpropagate, and update weights on GPU2
loss_fn = nn.CrossEntropyLoss()
loss = loss_fn(output2, target)
loss.backward()
optimizer.step()  # Update weights on GPU2

# Synchronize the GPUs to ensure proper communication (if needed)

# Repeat the process for multiple batches in a training loop
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[13], line 23
#      20 device1 = torch.device("cuda:0")
#      21 device2 = torch.device("cuda:1")
# ---> 23 model_gpu1 = LargeModel().to(device1)
#      24 model_gpu2 = LargeModel().to(device2)
#      26 # Define a dummy data batch
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.9/site-packages/torch/nn/modules/module.py:1145, in Module.to(self, *args, **kwargs)
#    1141         return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1142                     non_blocking, memory_format=convert_to_format)
#    1143     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
# -> 1145 return self._apply(convert)
#
# ...

# %%
# !pip install pymc3

# %%
import numpy as np
import pymc3 as pm
import matplotlib.pyplot as plt

# Generate synthetic data
np.random.seed(0)
x = np.linspace(0, 10, 100)
true_slope = 2.0
true_intercept = 1.0
y = true_slope * x + true_intercept + np.random.normal(0, 1, 100)

# Bayesian regression model
with pm.Model() as model:
    # Priors
    slope = pm.Normal("slope", mu=0, sigma=10)
    intercept = pm.Normal("intercept", mu=0, sigma=10)

    # Likelihood
    sigma = pm.HalfNormal("sigma", sigma=1)
    y_observed = pm.Normal("y_observed", mu=slope * x + intercept, sigma=sigma, observed=y)

    # MCMC sampling
    trace = pm.sample(2000, tune=1000, cores=2)

# Plot posterior distributions
pm.plot_posterior(trace, var_names=["slope", "intercept", "sigma"], figsize=(12, 6))
plt.show()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.9/site-packages/deprecat/classic.py:215: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   return wrapped_(*args_, **kwargs_)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma, intercept, slope]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
# ...
