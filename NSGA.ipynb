# 12715            0.992            0.992      0.0            8.0         6244.0
# 12716            0.992            0.992      0.0            8.0         6108.0
# 12717            0.992            0.992      1.0            8.0         5197.0
# 12718            0.992            0.992      0.0            8.0         5146.0
# 12719            0.992            0.992      0.0            8.0         3596.0
#
# [12720 rows x 93 columns]

# %%
import pandas as pd

# Assuming 'original_dataset' is your original DataFrame with many columns
# and 'columns_to_keep' is a list of 40 column names you want to select

# Example list of 40 column names you want to keep
features = ['setMFX2I01', 'setMFX1I03', 'setMFX0I01', 'setMFA0I03', 'setMFD0I04',
       'setMFX1dsch2', 'setMFX2dsch2', 'setMFX3dsch2', 'setMQS0L01',
       'setMQJ0L01', 'setMQS0L01A', 'setMQJ0L02', 'setMQS0L02', 'setMQJ0L02A',
       'setMQS0L02B', 'setMQJ0L03A', 'setMQS0L03', 'setMQJ0L03', 'setMQS0L04',
       'setMQJ0L04', 'PREBUNCHERphase', 'BUNCHERphase', 'booster07phase',
       'booster08phase', 'PREBUNCHERset', 'buncherset', 'booster07set',
       'booster08set', 'uf:nemixrms', 'uf:nemiyrms', 'uf:stdt',
        'uf:transmission', 'uf:stdx','uf:stdy', 'uf:stdEk_eV']

# Create a new DataFrame with only the 40 selected columns
new_dataset = df[features]

# Print the first few rows of the new dataset
print(new_dataset.head())
# Out:
#     setMFX2I01   setMFX1I03   setMFX0I01   setMFA0I03  setMFD0I04  \
# 0  2215.238830  2490.168048  1697.485756  1473.030786    2.537046
# 1  2185.359869  2518.957964  1675.905318  1440.990757    2.533038
# 2  2199.015005  2474.844626  1753.904597  1456.670791    2.563057
# 3  2165.687643  2488.146144  1638.508108  1459.215023    2.559686
# 4  2225.578494  2449.229969  1725.321464  1374.681384    2.594334
#
#    setMFX1dsch2  setMFX2dsch2  setMFX3dsch2  setMQS0L01  setMQJ0L01  ...  \
# 0   2017.056884    234.360462  -1789.319949    8.538248  -97.152055  ...
# 1   1951.116265   -195.652766  -1803.226694   -2.025642  -86.449055  ...
# 2   1970.830949   -285.409182  -1801.399507   16.501729  -87.556565  ...
# 3   1950.624308   -456.398438  -1833.970525   -5.897058  -80.995307  ...
# 4   1904.012831   -552.053450  -1788.709457   -1.868129  -68.980143  ...
#
#    buncherset  booster07set  booster08set   uf:nemixrms   uf:nemiyrms  \
# 0    0.000971  2.479212e+06  9.911478e+06  2.394730e-07  2.452264e-07
# 1    0.000910  2.463619e+06  9.890260e+06  2.144321e-07  2.400625e-07
# 2    0.000991  2.438387e+06  9.980006e+06  2.313929e-07  2.487747e-07
# 3    0.000969  2.473555e+06  9.920688e+06  2.336833e-07  2.462178e-07
# 4    0.000881  2.415524e+06  9.992310e+06  2.135632e-07  2.451856e-07
#
#         uf:stdt  uf:transmission   uf:stdx   uf:stdy   uf:stdEk_eV
# 0  4.416381e-13            0.992  0.000411  0.000791  72412.516837
# 1  4.507914e-13            0.992  0.000507  0.000519  70454.995792
# 2  4.338558e-13            0.992  0.000779  0.000119  72080.719404
# 3  4.331589e-13            0.992  0.000367  0.000865  64954.922758
#   8.16591304e-04 6.82540551e+04]
#  [2.28292302e-07 2.45353301e-07 4.96409168e-13 ... 5.12814702e-04
#   1.08663454e-04 7.25208402e+04]
#  ...
#  [2.24242251e-07 2.48975963e-07 4.53118946e-13 ... 5.20502156e-04
#   7.72759441e-04 7.16157201e+04]
#  [2.13278387e-07 2.48452560e-07 4.73644676e-13 ... 3.68903207e-04
#   2.93795934e-04 6.78127153e+04]
#  [2.25568999e-07 2.49755556e-07 4.74627514e-13 ... 4.41282049e-04
#   5.72573307e-04 7.73484692e+04]]

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
scaler_X = MinMaxScaler(feature_range=(-1.0, 1.0))
scaler_y = MinMaxScaler(feature_range=(-1.0, 1.0))

# Fit and transform X and y separately
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# To get back to the original data from the scaled data
#x_original = scaler_x.inverse_transform(x_scaled)
#y_original = scaler_y.inverse_transform(y_scaled)

# %%
 y_scaled
# Out:
# array([[-0.68979465, -0.7699023 , -0.75939189, ..., -0.49669717,
#         -0.32455982, -0.23860098],
#        [-0.77968519, -0.83620936, -0.51943641, ..., -0.86549452,
#         -0.21453619, -0.26868565],
#        [-0.57453529, -0.784709  , -0.09505234, ..., -0.60784899,
#         -0.90412495,  0.01416242],
#        ...,
#        [-0.62365823, -0.76080376, -0.71442361, ..., -0.59945108,
#         -0.25723258, -0.0458386 ],
#        [-0.7566386 , -0.7642576 , -0.42075343, ..., -0.7650604 ,
#         -0.72378838, -0.29794236],
#        [-0.60756614, -0.75565938, -0.40669155, ..., -0.6859925 ,
#         -0.45223282,  0.33418921]])

# %%
print(np.shape(X_scaled), np.shape(y_scaled))
# Out:
# (10000, 28) (10000, 7)

# %%
plt.figure()
plt.hist(X[:,0],color ='r')
plt.savefig('histogram_setMFX2I01.png')

# %%
plt.figure()
plt.hist(y[:,1],color ='b')
plt.savefig('histogram_normemity.png')
#from google.colab import files
#files.download( "histogram_normemity.png" )

# %%
import numpy as np
from sklearn.model_selection import train_test_split
split=75
# Step 1: Split data into training and testing sets (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size = (100 - split) / 100.,random_state = 42)
# Step 2: Further split the training set into training and validation sets (75% training, 25% validation)
#X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

def create_nn_model():
    model = keras.Sequential()
    model.add(layers.Dense(40, activation='tanh', input_shape=(28,)))
    model.add(layers.Dense(40, activation='tanh'))
    model.add(layers.Dense(40, activation='tanh'))
    model.add(layers.Dense(40, activation='tanh'))
    # Add the output layer with 7 nodes (one for each objective)
    model.add(layers.Dense(7))
    return model

# Define a function to generate and train a neural network model
model = create_nn_model()
y_prediction= model.predict(X_scaled)
# Out:
# 2024-03-07 11:59:02.028889: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2024-03-07 11:59:02.029355: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2024-03-07 11:59:02.029381: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2024-03-07 11:59:02.030297: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-03-07 11:59:02.031000: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2024-03-07 11:59:02.810888: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 313/313 [==============================] - 1s 1ms/step

# %%
import pygmo as pg
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import torch

# Load your data

# Define your custom neural network model
def create_nn_model():
    model = keras.Sequential()
    model.add(layers.Dense(40, activation='tanh', input_shape=(28,)))
    model.add(layers.Dense(40, activation='tanh'))
    model.add(layers.Dense(40, activation='tanh'))
    model.add(layers.Dense(40, activation='tanh'))
    # Add the output layer with 7 nodes (one for each objective)
    model.add(layers.Dense(7))
    return model

class CEBAFModel:
    def __init__(self):
        self.model =create_nn_model()
        #self.model.load_state_dict(torch.load(create_nn_model))        
        #path = os.path.realpath(os.path.relpath('../accelerator_toy_models/AWA_NN.pth'))
        self.features =['setMFX2I01', 'setMFX1I03', 'setMFX0I01', 'setMFA0I03', 'setMFD0I04',
             'setMFX1dsch2', 'setMFX2dsch2', 'setMFX3dsch2', 'setMQS0L01',
              'setMQJ0L01', 'setMQS0L01A', 'setMQJ0L02', 'setMQS0L02', 'setMQJ0L02A',
             'setMQS0L02B', 'setMQJ0L03A', 'setMQS0L03', 'setMQJ0L03', 'setMQS0L04',
               'setMQJ0L04', 'PREBUNCHERphase', 'BUNCHERphase', 'booster07phase',
                 'booster08phase', 'PREBUNCHERset', 'buncherset', 'booster07set',
                  'booster08set']
        self.targets = ['uf:nemixrms', 'uf:nemiyrms', 'uf:stdt','uf:transmission', 'uf:stdx','uf:stdy', 'uf:stdEk_eV']

    def predict(self, x):
        return self.model(x)
if __name__ == '__main__':
    CEBAFModel()


#class CustomProblem:
    #def __init__(self):
        #self.nvars = sum(w.size for w in create_nn_model().get_weights())
        #self.model = awa_model.AWAModel()
    
    #def get_nobj(self):
        #return 7

    #def fitness(self, x):
       # x = torch.tensor(x).reshape(1,-1).float()
        #return self.model.predict(x).detach().numpy().flatten().astype(float)
    
    #def get_bounds(self):
        #return ([-1]*6,[1]*6)
    
    #def fitness(self, x):
        # Convert the PyGMO vector x to a NumPy array
        #weights = np.array(x)
        
        # Evaluate the neural network with the given weights
        #objectives = evaluate_nn(weights)
        
        #return objectives

    #def get_bounds(self):
        # Define bounds for the PyGMO vector
        #lb = [-1.0] * self.nvars  # Lower bounds for all weights
        #ub = [1.0] * self.nvars   # Upper bounds for all weights
        #return (lb, ub)
    
    #def get_nobj(self):
        #return 7  # Replace with the number of objectives in your problem

#define problem class for pygmo
#class AWAProblem:
    #def __init__(self):
        #self.model = awa_model.AWAModel()
    
    #def get_nobj(self):
        #return 7

    #def fitness(self, x):
       # x = torch.tensor(x).reshape(1,-1).float()
        #return self.model.predict(x).detach().numpy().flatten().astype(float)
    
    #def get_bounds(self):
        #return ([-1]*6,[1]*6)

# Define your custom evaluation function
#def evaluate_nn(x):
    # Create a copy of the model to ensure no changes to the original model
#model = create_nn_model()
    # Set the weights of the model to the values in x
    #model.set_weights(x)
    
    # Use the model to make predictions on your data X_scaled
    #y_pred = model.predict(X_scaled)
    
    # Calculate your objectives from y_pred (you need to define your objectives)
    #objectives = y_pred  # Replace with your objective calculations
    
    #return objectives

# Define your custom problem class
#class CustomProblem:
    #def __init__(self):
        #self.nvars = sum(w.size for w in create_nn_model().get_weights())
    
    #def fitness(self, x):
        # Convert the PyGMO vector x to a NumPy array
        #weights = np.array(x)
        
        # Evaluate the neural network with the given weights
        #objectives = evaluate_nn(weights)
        
        #return objectives

    #def get_bounds(self):
        # Define bounds for the PyGMO vector
        #lb = [-1.0] * self.nvars  # Lower bounds for all weights
        #ub = [1.0] * self.nvars   # Upper bounds for all weights
        #return (lb, ub)
    
    #def get_nobj(self):
        #return 7  # Replace with the number of objectives in your problem

# Create the problem instance
#problem = pg.problem(CustomProblem())

# Create a population
#pop_size = 200
#pop = pg.population(problem, size=pop_size)

# Select an algorithm (e.g., NSGA-II)
#algo = pg.algorithm(pg.nsga2(gen=200, cr=0.85, m=0.05))

# Run optimization
#pop = algo.evolve(pop)

# Extract results
#fits, vectors = pop.get_f(), pop.get_x()

# Process the results as needed

# %%
# get CEBAF model
model = CEBAFModel()
#y_prediction= model.predict(X_scaled) 
#model = awa_model.AWAModel()
print(model.features)
print(model.targets)
#x = tf.convert_to_tensor(X_scaled, dtype=tf.float32)
model.predict(X_scaled)
# Out:
# ['setMFX2I01', 'setMFX1I03', 'setMFX0I01', 'setMFA0I03', 'setMFD0I04', 'setMFX1dsch2', 'setMFX2dsch2', 'setMFX3dsch2', 'setMQS0L01', 'setMQJ0L01', 'setMQS0L01A', 'setMQJ0L02', 'setMQS0L02', 'setMQJ0L02A', 'setMQS0L02B', 'setMQJ0L03A', 'setMQS0L03', 'setMQJ0L03', 'setMQS0L04', 'setMQJ0L04', 'PREBUNCHERphase', 'BUNCHERphase', 'booster07phase', 'booster08phase', 'PREBUNCHERset', 'buncherset', 'booster07set', 'booster08set']
# ['uf:nemixrms', 'uf:nemiyrms', 'uf:stdt', 'uf:transmission', 'uf:stdx', 'uf:stdy', 'uf:stdEk_eV']
# <tf.Tensor: shape=(10000, 7), dtype=float32, numpy=
# array([[-0.00696137,  0.80960834, -0.33127418, ...,  0.40307656,
#          0.28755462,  0.346551  ],
#        [ 0.18728308,  0.13907841, -0.10264918, ...,  0.2115674 ,
#         -0.5003028 , -0.0037867 ],
#        [-0.08630085, -0.0035891 ,  0.08511946, ..., -0.34868804,
#         -0.17203978, -0.3561548 ],
#        ...,
#        [ 0.060146  ,  0.555925  , -0.20416781, ...,  0.38663834,
#          0.01072565,  0.2273374 ],
#        [-0.28417078,  0.28317887, -0.06657043, ..., -0.00179991,
#          0.10215174, -0.02502054],
#        [-0.01906767, -0.12693591,  0.11243249, ..., -0.01248123,
#         -0.4497567 , -0.00686447]], dtype=float32)>

# %%
print(np.shape(X_scaled), np.shape(model.predict(X_scaled)))
# Out:
# (10000, 28) (10000, 7)

# %%
import torch

# Assuming X_scaled is your NumPy ndarray
x = torch.from_numpy(X_scaled)

# %%
#define problem class for pygmo
class CEBAFProblem:
    def __init__(self):
        self.model = CEBAFModel()
    
    def get_nobj(self):
        return 7
    def fitness(self, x):
        x = torch.tensor(x).float()  # Convert input to PyTorch tensor
        predictions = self.model(x)  # Use the PyTorch model directly
        predictions = predictions.detach().numpy().flatten().astype(float)
        return predictions

    #def fitness(self, x):
        #x = torch.tensor(x).reshape(1, -1).float()
        #predictions = self.model.predict(x)
       # predictions = predictions.detach().numpy().flatten().astype(float)
        #return predictions
    #ef fitness(self, x):
        #x = torch.tensor(x).reshape(1,-1).float()
        #return self.model.predict(x).detach().numpy().flatten().astype(float)
    
    def get_bounds(self):
        return ([-1]*28,[1]*28)

# %%
import pygmo as pg
import torch
import numpy as np

# Define your custom neural network model
class CustomNNModel(torch.nn.Module):
    def __init__(self):
        super(CustomNNModel, self).__init__()
        self.fc1 = torch.nn.Linear(28, 40)
        self.fc2 = torch.nn.Linear(40, 40)
        self.fc3 = torch.nn.Linear(40, 40)
        self.fc4 = torch.nn.Linear(40, 40)
        self.output_layer = torch.nn.Linear(40, 7)

    def forward(self, x):
        x = torch.tanh(self.fc1(x))
        x = torch.tanh(self.fc2(x))
        x = torch.tanh(self.fc3(x))
        x = torch.tanh(self.fc4(x))
        x = self.output_layer(x)
        return x

# Create an instance of your neural network model
neural_net = CustomNNModel()

# Define your PyGMO problem
class CustomProblem:
    def __init__(self):
        self.neural_net = neural_net
    
    def fitness(self, x):
        x = torch.tensor(x, dtype=torch.float32)  # Convert input to PyTorch tensor
        predictions = self.neural_net(x)  # Use the PyTorch model directly
        predictions = predictions.detach().numpy().flatten().astype(float)
        return predictions
    
    def get_bounds(self):
        return ([-1.0] * 28, [1] * 28)

    def get_nobj(self):
        return 7

# Create the optimization problem
problem = pg.problem(CustomProblem())

# Create the population
pop_size = 300
pop = pg.population(problem, size=pop_size)
# Select the algorithm (e.g., NSGA-II)
algo = pg.algorithm(pg.nsga2(gen=100000, cr = 0.95, m = 0.02))
algo.set_verbosity(100)
# Print the algorithm
print(algo)

# Run the optimization
pop = algo.evolve(pop)

# Extract results
fits, vectors = pop.get_f(), pop.get_x()

# Now you can analyze the optimization results
# Out:
# Algorithm name: NSGA-II: [stochastic]
# 	C++ class name: pagmo::nsga2
#
# 	Thread safety: basic
#
# Extra info:
# 	Generations: 100000
# 	Crossover probability: 0.95
# 	Distribution index for crossover: 10
# 	Mutation probability: 0.02
# 	Distribution index for mutation: 50
# 	Seed: 3686778940
# 	Verbosity: 100
#
#    Gen:        Fevals:        ideal1:        ideal2:        ideal3:        ideal4:        ideal5:          ... :
#       1              0     -0.0400787      -0.196484        0.10993      -0.224616      0.0733109
#     101          30000      -0.125564      -0.277285      0.0413911      -0.322599     -0.0093699
#     201          60000      -0.129994      -0.294862      0.0331316      -0.328747     -0.0137987
#     301          90000      -0.134038      -0.298538      0.0293625      -0.334146     -0.0164982
#     401         120000       -0.13467      -0.299969      0.0276746      -0.335873     -0.0188927
#     501         150000      -0.136772      -0.301013      0.0272148      -0.339735     -0.0217728
#     601         180000      -0.137207      -0.302482      0.0256303      -0.341085      -0.022398
#     701         210000       -0.13871      -0.302897      0.0256303      -0.343315     -0.0227999
#     801         240000      -0.139066      -0.302929      0.0249988       -0.34339     -0.0231413
#     901         270000       -0.14016      -0.303554      0.0237188      -0.345174     -0.0246261
#    1001         300000      -0.141406      -0.303615      0.0237092      -0.345174     -0.0255192
#    1101         330000      -0.141719      -0.303754      0.0236517      -0.345467     -0.0262843
#    1201         360000      -0.143017      -0.305032      0.0236373      -0.345616      -0.026379
#    1301         390000      -0.143064      -0.305033      0.0234786       -0.34564      -0.026769
      -0.149076      -0.310133      0.0209129      -0.349675     -0.0312608
#   97801       29340000      -0.149076      -0.310133      0.0209129      -0.349675     -0.0312608
#   97901       29370000      -0.149076      -0.310133      0.0209129      -0.349675

# %%
y_optimized =scaler_y.inverse_transform(fits)
# Visualize the Pareto front
import matplotlib.pyplot as plt
plt.scatter(y_optimized[:, 0], y_optimized[:, 2])  # Assuming 2 objectives
plt.xlabel('Objective 1')
plt.ylabel('Objective 2')
plt.title('Pareto Front')
plt.show()

# %%
import random
import numpy as np
import tensorflow as tf
from deap import base, creator, tools, algorithms

# Define your custom neural network model using TensorFlow
class CustomNNModel(tf.keras.Model):
    def __init__(self):
        super(CustomNNModel, self).__init__()
        self.fc1 = tf.keras.layers.Dense(40, activation='tanh', input_shape=(28,))
        self.fc2 = tf.keras.layers.Dense(40, activation='tanh')
        self.fc3 = tf.keras.layers.Dense(40, activation='tanh')
        self.fc4 = tf.keras.layers.Dense(40, activation='tanh')
        self.output_layer = tf.keras.layers.Dense(7)

    def call(self, x):
        x = tf.tanh(self.fc1(x))
        x = tf.tanh(self.fc2(x))
        x = tf.tanh(self.fc3(x))
        x = tf.tanh(self.fc4(x))
        x = self.output_layer(x)
        return x

# Create an instance of your neural network model
neural_net = CustomNNModel()

# Define your evaluation function
def evaluate(individual):
    x = tf.convert_to_tensor([individual], dtype=tf.float32)  # Convert input to TensorFlow tensor
    predictions = neural_net(x)  # Use the TensorFlow model directly
    predictions = predictions.numpy().flatten().astype(float)
    return predictions

# Create the DEAP toolbox
creator.create("FitnessMulti", base.Fitness, weights=(-1.0,) * 7)  # Minimize 7 objectives
creator.create("Individual", list, fitness=creator.FitnessMulti)

toolbox = base.Toolbox()
toolbox.register("attr_float", random.uniform, -1, 1)  # Define variable bounds
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, n=28)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("evaluate", evaluate)
toolbox.register("mate", tools.cxBlend, alpha=0.85)  # Crossover
toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=0.2, indpb=0.2)  # Mutation
toolbox.register("select", tools.selNSGA2)

# Create the population
pop_size = 120
pop = toolbox.population(n=pop_size)

# Define the statistics object to collect optimization results
stats = tools.Statistics(lambda ind: ind.fitness.values)
stats.register("min", np.min, axis=0)

# Create the optimization algorithm (NSGA-II)
n_gen = 1000
mu, lambda_ = 120, 100
cxpb, mutpb = 0.7, 0.2
algorithms.eaMuPlusLambda(pop, toolbox, mu, lambda_, cxpb, mutpb, n_gen, stats, halloffame=None)

# Extract the final population
final_pop = pop[:]

# Extract results
fits = np.array([ind.fitness.values for ind in final_pop])
vectors = np.array([ind for ind in final_pop])
# Out:
# gen	nevals	min
# 0  	120   	[-0.71947038 -0.70264471 -0.73808193 -0.80868119 -0.88145196 -1.22520185
#  -0.56565237]
# 1  	89    	[-0.84870768 -0.76063722 -0.75564492 -0.81661719 -0.88145196 -1.22520185
#  -0.59448755]
# 2  	90    	[-0.84870768 -0.76063722 -0.75564492 -0.81661719 -1.23044419 -1.22520185
#  -0.75379336]
# 3  	88    	[-0.84870768 -0.97157931 -0.75564492 -0.83402789 -1.23044419 -1.22520185
#  -0.75379336]
# 4  	92    	[-0.84870768 -0.97157931 -0.75564492 -0.83402789 -1.23044419 -1.34141314
#  -0.80161345]
# 5  	94    	[-0.84870768 -1.02014494 -0.90844637 -0.94017369 -1.23044419 -1.34141314
#  -0.80161345]
# 6  	94    	[-0.84870768 -1.02014494 -0.90844637 -0.94017369 -1.23044419 -1.34141314
#  -0.91919357]
#  -1.10439539]
# 990	94    	[-1.21296537 -1.37104952 -1.13165247 -1.11405575 -1.45832348 -1.7062161
#  -1.10439539]
# 991	87    	[-1.21296537 -1.37104952 -1.13165247 -1.11405575 -1.35024488 -1.7062161
#  -1.10439539]
# 992	88    	[-1.21296537 -1.37104952 -1.13165247 -1.11405575 -1.35024488 -1.7062161
#  -1.10439539]
# 993	87    	[-1.21296537 -1.37104952 -1.13165247 -1.11405575 -1.35024488 -1.7062161
#  -1.10439539]
# 994	91    	[-1.21296537 -1.37104952 -1.19714034 -1.11405575 -1.35024488 -1.7062161
#  -1.10439539]
# 995	92    	[-1.21296537 -1.37104952 -1.19714034 -1.11405575 -1.35024488 -1.7062161
#  -1.10439539]
# 996	90    	[-1.21296537 -1.37104952 -1.19714034 -1.11405575 -1.35024488 -1.7062161
#  -1.10439539]
# 997	88    	[-1.21296537 -1.37104952 -1.16951954 -1.11405575 -1.36364353 -1.7062161
#  -1.10439539]
# 998	96    	[-1.21296537 -1.37104952 -1.16951954 -1.11405575 -1.36364353 -1.7062161
#  -1.10439539]
# 999	90    	[-1.21296537 -1.37104952 -1.16951954 -1.11405575 -1.36364353 -1.7062161
#  -1.10439539]
# 1000	89    	[-1.21296537 -1.37104952 -1.16951954 -1.11405575 -1.36364353 -1.7062161
#  -1.10439539]

# %%
print(np.shape(fits), np.shape(vectors))
# Out:
# (120, 7) (120, 28)

# %%
y_optimized =scaler_y.inverse_transform(fits)
#print(y_optimized)
# Visualize the Pareto front

# %%
print(y_optimized[50:75,0], fits[50:75, 0])  # Assuming 2 objectives
# Out:
# [2.47672495e-07 2.71254484e-07 2.81725833e-07 2.18098228e-07
#  2.82592903e-07 2.72591616e-07 2.01968901e-07 1.99026000e-07
#  2.68454050e-07 2.53189450e-07 2.77599017e-07 2.21603299e-07
#  2.61309795e-07 2.61309795e-07 2.61309795e-07 2.05751396e-07
#  3.01972714e-07 2.80267905e-07 2.89220240e-07 2.84777587e-07
#  2.06191736e-07 2.49757685e-07 2.69069861e-07 2.60671075e-07
#  3.11587903e-07] [ 0.52959764 -0.57639617 -0.57639617 -0.43365359 -0.43365359 -0.5579133
#   0.01686297  0.56651342 -0.05339118 -0.83808219 -0.61081368  1.13894868
#   0.24462119 -0.51187539 -0.51187539 -1.37601709  0.29580867 -0.26237443
#  -0.7111392  -0.61441529 -0.42543787 -0.05395076  0.11064919  0.4849695
#  -0.2854071 ]

# %%
import random
import numpy as np
import tensorflow as tf
from deap import base, creator, tools, algorithms

# Define your custom neural network model using TensorFlow
class CustomNNModel(tf.keras.Model):
    def __init__(self):
        super(CustomNNModel, self).__init__()
        self.fc1 = tf.keras.layers.Dense(40, activation='tanh', input_shape=(28,))
        self.fc2 = tf.keras.layers.Dense(40, activation='tanh')
        self.fc3 = tf.keras.layers.Dense(40, activation='tanh')
        self.fc4 = tf.keras.layers.Dense(40, activation='tanh')
        self.output_layer = tf.keras.layers.Dense(7)

    def call(self, x):
        x = tf.tanh(self.fc1(x))
        x = tf.tanh(self.fc2(x))
        x = tf.tanh(self.fc3(x))
        x = tf.tanh(self.fc4(x))
        x = self.output_layer(x)
        return x

# Create an instance of your neural network model
neural_net = CustomNNModel()

# Define your evaluation function
#def evaluate(individual):
   # x = tf.convert_to_tensor([individual], dtype=tf.float32)  # Convert input to TensorFlow tensor
    #predictions = neural_net(x)  # Use the TensorFlow model directly
   # predictions = predictions.numpy().flatten().astype(float)
    #return predictions
# Define your evaluation function
def evaluate(individual):
    x = tf.convert_to_tensor([individual], dtype=tf.float32)  # Convert input to TensorFlow tensor
    predictions = neural_net(x)  # Use the TensorFlow model directly
    predictions = predictions.numpy().flatten().astype(float)
    
    # Create a list to store objectives
    objectives = []
    
    # Check each objective against the constraint
    for i in range(len(predictions)):
        if i == 0 and predictions[i] > -0.32:
            # Skip this objective, as it violates the constraint
            continue
        objectives.append(predictions[i])  # Add the objective value to the objectives list
    
    # Ensure that you have 7 objectives; if not, fill the missing ones with a default value
    while len(objectives) < 7:
        objectives.append(0.0)  # Fill missing objectives with 0.0
    
    return tuple(objectives)

# Create the DEAP toolbox
creator.create("FitnessMulti", base.Fitness, weights=(-1.0,) * 7)  # Minimize 7 objectives
creator.create("Individual", list, fitness=creator.FitnessMulti)

toolbox = base.Toolbox()
toolbox.register("attr_float", random.uniform, -1, 1)  # Define variable bounds
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, n=28)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("evaluate", evaluate)
toolbox.register("mate", tools.cxBlend, alpha=0.85)  # Crossover
toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=0.2, indpb=0.2)  # Mutation
toolbox.register("select", tools.selNSGA2)

# Create the population
pop_size = 120
pop = toolbox.population(n=pop_size)

# Define the statistics object to collect optimization results
stats = tools.Statistics(lambda ind: ind.fitness.values)
stats.register("min", np.min, axis=0)

# Create the optimization algorithm (NSGA-II)
n_gen = 100
mu, lambda_ = 120, 100
cxpb, mutpb = 0.7, 0.2
algorithms.eaMuPlusLambda(pop, toolbox, mu, lambda_, cxpb, mutpb, n_gen, stats, halloffame=None)

# Extract the final population
final_pop = pop[:]

# Extract results
fits = np.array([ind.fitness.values for ind in final_pop])
vectors = np.array([ind for ind in final_pop])
# Out:
# gen	nevals	min
# 0  	120   	[-1.10437965 -0.62587035 -0.69583768 -0.60089052 -0.87601751 -0.64312297
#  -0.41731495]
# 1  	93    	[-1.10437965 -0.74232507 -0.69583768 -0.68566036 -0.87601751 -0.65996897
#  -0.41731495]
# 2  	84    	[-1.10437965 -1.0241735  -0.69583768 -0.68566036 -0.87601751 -0.65996897
#  -0.41731495]
# 3  	95    	[-1.10437965 -1.0241735  -0.71889341 -0.76303804 -0.990426   -0.76315045
#  -0.57279432]
# 4  	85    	[-1.10437965 -1.0241735  -0.71889341 -0.76303804 -1.03363299 -0.80825227
#  -0.57279432]
# 5  	91    	[-1.10437965 -1.0241735  -0.78122276 -0.93464494 -1.03363299 -1.24971056
#  -0.61028099]
# 6  	86    	[-1.10437965 -1.0241735  -0.78122276 -0.93464494 -1.03363299 -1.24971056
#  -0.61028099]
# 7  	91    	[-1.11183977 -1.0241735  -0.83168447 -0.93464494 -1.05431199 -1.24971056
#  -0.61028099]
# 84 	91    	[-1.19025803 -1.10709524 -1.05787599 -1.23378277 -1.43932033 -1.51943803
#  -0.87529588]
# 85 	84    	[-1.19025803 -1.10709524 -1.05787599 -1.30608678 -1.43932033 -1.51943803
#  -0.87529588]
# 86 	92    	[-1.14566314 -1.18312514 -1.05787599 -1.30608678 -1.43932033 -1.51943803
#  -0.87529588]
# 87 	87    	[-1.14566314 -1.20810044 -1.05787599 -1.30608678 -1.43932033 -1.51943803
#  -0.90704679]
# 88 	90    	[-1.14566314 -1.20810044 -1.05787599 -1.30608678 -1.42351675 -1.51943803
#  -0.90704679]
# 89 	87    	[-1.14566314 -1.20810044 -1.06257236 -1.30608678 -1.42791843 -1.51943803
#  -0.90704679]
# 90 	94    	[-1.36103404 -1.20810044 -1.06257236 -1.30608678 -1.43457437 -1.51943803
#  -0.90704679]
# 91 	92    	[-1.36103404 -1.20810044 -1.14268661 -1.30608678 -1.43457437 -1.51943803
#  -0.90704679]
# 92 	95    	[-1.43764949 -1.20810044 -1.14268661 -1.30608678 -1.43457437 -1.54659975
#  -0.90873247]
# 93 	89    	[-1.43764949 -1.20810044 -1.14268661 -1.30608678 -1.43457437 -1.54659975
#  -0.90873247]
# 94 	89    	[-1.43764949 -1.20810044 -1.14268661 -1.30608678 -1.43457437 -1.51943803
#  -0.90873247]
# 95 	94    	[-1.43764949 -1.20810044 -1.14268661 -1.30608678 -1.43457437 -1.51943803
#  -0.90873247]
# 96 	89    	[-1.43764949 -1.20810044 -1.01159751 -1.30608678 -1.43457437 -1.51943803
#  -0.90873247]
# 97 	88    	[-1.43764949 -1.20810044 -1.01159751 -1.30810988 -1.43457437 -1.52601337
#  -0.9195081 ]
# 98 	93    	[-1.43764949 -1.20810044 -1.01159751 -1.30810988 -1.43457437 -1.52601337
#  -0.93511772]
# 99 	90    	[-1.43764949 -1.20810044 -1.01159751 -1.30811012 -1.43457437 -1.53966486
#  -0.93511772]
# 100	88    	[-1.43764949 -1.20810044 -1.0269748  -1.30811012 -1.43457437 -1.53966486
#  -0.93511772]

# %%
# Visualize the Pareto front
import matplotlib.pyplot as plt
plt.scatter(y_optimized[:, 0], y_optimized[:, 2])  # Assuming 2 objectives
plt.xlabel('Objective 1')
plt.ylabel('Objective 2')
plt.title('Pareto Front')
plt.show()

# %%
# Extract optimized settings (variables) and objectives
optimized_settings = vectors  # This contains the optimized variable settings
optimized_objectives = fits    # This contains the optimized objective values

# Now you can save these results as needed
np.savetxt('optimized_settings.csv', optimized_settings, delimiter=',')
np.savetxt('optimized_objectives.csv', optimized_objectives, delimiter=',')

# %%
y_optimized =scaler_y.inverse_transform(fits)
x_optimized = scaler_X.inverse_transform(vectors)

# %%
y_optimized
# Out:
# array([[2.62261845e-07, 3.66152837e-07, 4.93275971e-13, 8.30769946e-02,
#         9.39639816e-04, 1.08840604e-03, 7.12830500e+04],
#        [2.63395675e-07, 3.79159828e-07, 4.98856369e-13, 8.06722663e-02,
#         9.62579280e-04, 1.03135469e-03, 6.83637019e+04],
#        [2.66278900e-07, 3.67493373e-07, 5.05545620e-13, 7.64492965e-02,
#         1.05445374e-03, 9.41571143e-04, 7.16271508e+04],
#        [2.61745997e-07, 3.79527235e-07, 4.96745637e-13, 8.19791514e-02,
#         9.59637610e-04, 1.05343896e-03, 6.92503418e+04],
#        [2.65393262e-07, 3.81307071e-07, 5.04445047e-13, 8.09330959e-02,
#         1.00854719e-03, 9.71929583e-04, 6.95422773e+04],
#        [2.72909164e-07, 3.63282307e-07, 5.08204065e-13, 7.27784852e-02,
#         1.11481697e-03, 9.34810215e-04, 7.16065355e+04],
#        [2.70885271e-07, 3.66302691e-07, 5.10880046e-13, 7.80148955e-02,
#         1.09622607e-03, 8.77236318e-04, 7.17937839e+04],
#        [2.56007181e-07, 3.69717360e-07, 4.99435899e-13, 7.80956377e-02,
#         8.81609404e-04, 9.97255699e-04, 7.04471588e+04],
#        [2.72817282e-07, 3.57784143e-07, 5.05272127e-13, 7.41012728e-02,
#         1.14405539e-03, 9.29051354e-04, 7.17512754e+04],
#        [2.55738655e-07, 3.70035384e-07, 4.99436648e-13, 7.82816912e-02,
#         8.73805734e-04, 9.99908456e-04, 7.04105997e+04],
#        [2.58706968e-07, 3.71653592e-07, 4.99613389e-13, 8.20033607e-02,
#         8.43449997e-04, 1.04230424e-03, 6.97298504e+04],
#        [2.62016521e-07, 3.65976523e-07, 4.94781881e-13, 8.39991544e-02,
#         8.91201608e-04, 1.07810976e-03, 7.03451791e+04],
#        [2.71174659e-07, 3.41337476e-07, 5.03977722e-13, 7.26359934e-02,
#         1.04346740e-03, 9.75956988e-04, 7.24664869e+04],
#        [2.62432905e-07, 3.64828787e-07, 5.02094526e-13, 7.49818938e-02,
#         1.00196951e-03, 9.98736419e-04, 7.10624924e+04],
#        [2.70732157e-07, 3.44318681e-07, 5.04354783e-13, 7.29529896e-02,
#         1.03852920e-03, 9.86339273e-04, 7.28614996e+04],
#        [2.71635206e-07, 3.61684015e-07, 5.09229447e-13, 7.65580305e-02,
#         1.09635612e-03, 8.90685894e-04, 7.15466635e+04],
#        [2.64285558e-07, 3.79981516e-07, 5.01298735e-13, 8.06953386e-02,
#         9.55694675e-04, 9.94642433e-04, 6.91281499e+04]])

# %%
# front hypervolume
# front hypervolume
hv = pg.hypervolume(pop)
ref_point = np.ones(7)
hv.compute(ref_point)
# Out:
# 1.63319142132959

# %%
plt.plot(y_optimized[:,0], y_optimized[:,2], 'o')
plt.legend(loc=0)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pygmo as pg
import torch
import numpy as np

# Define your custom neural network model
class CustomNNModel(torch.nn.Module):
    def __init__(self):
        super(CustomNNModel, self).__init__()
        self.fc1 = torch.nn.Linear(28, 40)
        self.fc2 = torch.nn.Linear(40, 40)
        self.fc3 = torch.nn.Linear(40, 40)
        self.fc4 = torch.nn.Linear(40, 40)
        self.output_layer = torch.nn.Linear(40, 7)

    def forward(self, x):
        x = torch.tanh(self.fc1(x))
        x = torch.tanh(self.fc2(x))
        x = torch.tanh(self.fc3(x))
        x = torch.tanh(self.fc4(x))
        x = self.output_layer(x)
        return x

# Create an instance of your neural network model
neural_net = CustomNNModel()

# Define your PyGMO problem
class CustomProblem:
    def __init__(self):
        self.neural_net = neural_net
    
    def fitness(self, x):
        x = torch.tensor(x, dtype=torch.float32)  # Convert input to PyTorch tensor
        predictions = self.neural_net(x)  # Use the PyTorch model directly
        predictions = predictions.detach().numpy().flatten().astype(float)
        return predictions
    
    def get_bounds(self):
        return ([-1.0] * 28, [1.0] * 28)

    def get_nobj(self):
        return 7

# Create the optimization problem
problem = pg.problem(CustomProblem())

# Select the NSGA-II algorithm with increased generations and population size
#algo = pg.algorithm(pg.nsga2(gen=1000, cr=0.85, m=0.01))  # Adjusted parameters  Create an algorithm (e.g., NSGA-II)
algo = pg.algorithm(pg.nsga2(gen=1000, cr=0.9, eta_c=2.0, m=0.1, eta_m=2.0))

algo.set_verbosity(100)

# Print the algorithm
print(algo)
# Create a population

pop_size = 120
pop = pg.population(problem, size=pop_size)

# Evolve the population using the algorithm
pop = algo.evolve(pop)

# Retrieve the optimization log
optimization_log = algo.extract(pg.nsga2).get_log()

# Extract results
fits, vectors = pop.get_f(), pop.get_x()

# Compute hypervolume
#hv = pg.hypervolume(pop)
#ref_point = np.array(1,1,1,1,1,1.1)
#hypervolume_value = hv.compute(ref_point)

#print("Hypervolume:", hypervolume_value)
# Out:
# Algorithm name: NSGA-II: [stochastic]
# 	C++ class name: pagmo::nsga2
#
# 	Thread safety: basic
#
# Extra info:
# 	Generations: 1000
# 	Crossover probability: 0.9
# 	Distribution index for crossover: 2
# 	Mutation probability: 0.1
# 	Distribution index for mutation: 2
# 	Seed: 1023636083
# 	Verbosity: 100

# %%
fronts = pg.fast_non_dominated_sorting(fits)
pareto_front_0 = fronts[0]
pareto_optimal_solutions = vectors[pareto_front_0]
pareto_optimal_solutions
# Out:
# /var/folders/t7/yy62typn4y1cknks8l305k2h0000gn/T/ipykernel_41094/595958376.py:3: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   pareto_optimal_solutions = vectors[pareto_front_0]
# array([[-0.99996808, -0.80331827, -0.61659989, ...,  0.96044187,
#          0.98894453, -0.9999693 ],
#        [-0.99939538,  0.9829158 ,  0.99104821, ...,  0.87346517,
#          0.97384264, -0.98110603],
#        [-0.99875938, -0.9888161 , -0.99111031, ...,  0.99963578,
#          0.9361117 ,  0.99544832],
#        ...,
#        [-0.99820936, -0.99388986, -0.89060107, ..., -0.07444454,
#          0.80416123,  0.9980092 ],
#        [-0.81511207,  0.3010879 , -0.98313198, ..., -0.67894325,
#          0.76397551,  0.99753051],
#        [-0.99939538,  0.94026513,  0.99104821, ...,  0.87346517,
#          0.97384264, -0.97456139]])

# %%
optimization_log
# Out:
# [(1,
#   0,
#   array([-0.16888696, -0.03078107, -0.0495607 ,  0.00730626, -0.14922941,
#          -0.08557683, -0.16243428])),
#  (101,
#   12000,
#   array([-0.22767922, -0.13122638, -0.11759534, -0.09033866, -0.25540206,
#          -0.13929844, -0.24036637])),
#  (201,
#   24000,
#   array([-0.23862174, -0.1397673 , -0.12648839, -0.10474963, -0.2581774 ,
#          -0.15091263, -0.2496485 ])),
#         1.04346740e-03, 9.75956988e-04, 7.24664869e+04],
#        [2.62432905e-07, 3.64828787e-07, 5.02094526e-13, 7.49818938e-02,
#         1.00196951e-03, 9.98736419e-04, 7.10624924e+04],
#        [2.70732157e-07, 3.44318681e-07, 5.04354783e-13, 7.29529896e-02,
#         1.03852920e-03, 9.86339273e-04, 7.28614996e+04],
#        [2.71635206e-07, 3.61684015e-07, 5.09229447e-13, 7.65580305e-02,
#         1.09635612e-03, 8.90685894e-04, 7.15466635e+04],
#        [2.64285558e-07, 3.79981516e-07, 5.01298735e-13, 8.06953386e-02,
#         9.55694675e-04, 9.94642433e-04, 6.91281499e+04]])

# %%
num_generations = pop.get_log()[:, 0].size
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 num_generations = pop.get_log()[:, 0].size
#
# AttributeError: 'pygmo.core.population' object has no attribute 'get_log'

# %%
fits
# Out:
# array([[ 0.05363869,  0.01247665, -0.1597347 , ..., -0.07703665,
#         -0.00334939,  0.1074158 ],
#        [ 0.12475857, -0.14017522, -0.14092663, ...,  0.0548875 ,
#         -0.18540232,  0.22122872],
#        [ 0.08500212, -0.11410477, -0.06718343, ...,  0.16772431,
#         -0.27564651,  0.13620424],
#        ...,
#        [ 0.03875548,  0.03463696, -0.03657894, ...,  0.09195464,
#         -0.02592359,  0.04982977],
#        [-0.06434567, -0.08238786,  0.01344267, ...,  0.18614292,
#         -0.04073244,  0.03525732],
#        [-0.01500689, -0.12861167, -0.0433839 , ...,  0.11842343,
#         -0.04450192,  0.0736381 ]])

# %%
import numpy as np
import tensorflow as tf

# Check data type
print(type(X_scaled))

# Check data shape
print(X_scaled.shape)
# Out:
# <class 'numpy.ndarray'>
# (10000, 28)

# %%
import pygmo as pg
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Load your data
X_scaled = ...  # Replace with your actual data

# Define your custom neural network model
def create_nn_model():
    model = keras.Sequential()
    model.add(layers.Dense(40, activation='tanh', input_shape=(28,)))
    model.add(layers.Dense(40, activation='tanh'))
    model.add(layers.Dense(40, activation='tanh'))
    model.add(layers.Dense(40, activation='tanh'))
    # Add the output layer with 7 nodes (one for each objective)
    model.add(layers.Dense(7))
    return model

# Define your custom evaluation function
#def evaluate_nn(x):
    # Create a copy of the model to ensure no changes to the original model
    #model = create_nn_model()
    # Set the weights of the model to the values in x
    #model.set_weights(x)
    
    # Use the model to make predictions on your data X_scaled
    #y_pred = model.predict(X_scaled)
    
    # Calculate your objectives from y_pred (you need to define your objectives)
    objectives = ...  # Replace with your objective calculations
    
    return objectives

# Define your custom problem class
class CustomProblem:
    def __init__(self):
        self.nvars = sum(w.size for w in create_nn_model().get_weights())
    
    def fitness(self, x):
        # Convert the PyGMO vector x to a NumPy array
        weights = x.to_array()
        
        # Evaluate the neural network with the given weights
        objectives = evaluate_nn(weights)
        
        return objectives

    def get_bounds(self):
        # Define bounds for the PyGMO vector
        lb = [-1.0] * self.nvars  # Lower bounds for all weights
        ub = [1.0] * self.nvars   # Upper bounds for all weights
        return (lb, ub)
    
    def get_nobj(self):
        return 7  # Replace with the number of objectives in your problem

# Create the problem instance
problem = pg.problem(CustomProblem())

# Create a population
pop_size = 200
pop = pg.population(problem, size=pop_size)

# Select an algorithm (e.g., NSGA-II)
algo = pg.algorithm(pg.nsga2(gen=200, cr=0.85, m=0.05))

# Run optimization
pop = algo.evolve(pop)

# Extract results
fits, vectors = pop.get_f(), pop.get_x()

# Process the results as needed
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 64
#      62 # Create a population
#      63 pop_size = 200
# ---> 64 pop = pg.population(problem, size=pop_size)
#      66 # Select an algorithm (e.g., NSGA-II)
#      67 algo = pg.algorithm(pg.nsga2(gen=200, cr=0.85, m=0.05))
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.9/site-packages/pygmo/__init__.py:296, in _population_init(self, prob, size, b, seed)
#     292     seed = _random_device_next()
#     294 if b is None:
#     295     # No bfe specified, init in sequential mode.
# --> 296     __original_population_init(self, prob, size, seed)
#     297 else:
#     298     # A bfe was specified. Same as above with the problem.
#     299     __original_population_init(self, prob, b if type(
#     300         b) == bfe else bfe(b), size, seed)
#
# Cell In[34], line 43, in CustomProblem.fitness(self, x)
#      41 def fitness(self, x):
#      42     # Convert the PyGMO vector x to a NumPy array
# ---> 43     weights = x.to_array()
#      45     # Evaluate the neural network with the given weights
#      46     objectives = evaluate_nn(weights)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_array'

# %%
import pygmo as pg
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Load your data
#X_scaled = ...  # Replace with your actual data

# Define your custom neural network model
def create_nn_model():
    model = keras.Sequential()
    model.add(layers.Dense(40, activation='tanh', input_shape=(28,)))
    model.add(layers.Dense(40, activation='tanh'))
    model.add(layers.Dense(40, activation='tanh'))
    model.add(layers.Dense(40, activation='tanh'))
    # Add the output layer with 7 nodes (one for each objective)
    model.add(layers.Dense(7))
    return model

# Define your custom evaluation function
def evaluate_nn(x):
    # Create a copy of the model to ensure no changes to the original model
    model = create_nn_model()
    # Set the weights of the model to the values in x
    model.set_weights(x)
    
    # Use the model to make predictions on your data X_scaled
    y_pred = model.predict(X_scaled)
    
    # Calculate your objectives from y_pred (you need to define your objectives)
    objectives = ...  # Replace with your objective calculations
    
    return objectives

# Define your custom problem class
class CustomProblem:
    def __init__(self):
        self.nvars = sum(w.size for w in create_nn_model().get_weights())
    
    def fitness(self, x):
        # Convert the PyGMO vector x to a list of NumPy arrays
        weights = pg.var_to_doubles(x)
        
        # Evaluate the neural network with the given weights
        objectives = evaluate_nn(weights)
        
        return objectives

    def get_bounds(self):
        # Define bounds for the PyGMO vector
        lb = [-1.0] * self.nvars  # Lower bounds for all weights
        ub = [1.0] * self.nvars   # Upper bounds for all weights
        return (lb, ub)
    
    def get_nobj(self):
        return 7  # Replace with the number of objectives in your problem

# Create the problem instance
problem = pg.problem(CustomProblem())

# Create a population
pop_size = 200
pop = pg.population(problem, size=pop_size)

# Select an algorithm (e.g., NSGA-II)
algo = pg.algorithm(pg.nsga2(gen=200, cr=0.85, m=0.05))

# Run optimization
pop = algo.evolve(pop)

# Extract results
fits, vectors = pop.get_f(), pop.get_x()

# Process the results as needed

# %%
features =

# %%
import random
import numpy as np
from deap import base, creator, tools, algorithms

# Define the optimization problem
creator.create("FitnessMulti", base.Fitness, weights=(-1.0,) * 7)  # Minimize all seven objectives
creator.create("Individual", list, fitness=creator.FitnessMulti)

# Define the bounds for your 28 variables (features)
BOUND_LOW = [-1.0] * 28  # Replace with your lower bounds for each variable
BOUND_UP = [1.0] * 28   # Replace with your upper bounds for each variable

# Create the DEAP toolbox
toolbox = base.Toolbox()

def random_float(minval, maxval):
    return random.uniform(minval, maxval)

# Register attribute, individual initialization, and population creation
toolbox.register("attr_float", random_float, BOUND_LOW, BOUND_UP)
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, n=28)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

# Define the evaluation function
def evaluate(individual):
    # Extract the features from the individual
    features = np.array(individual)
    
    # Use your neural network model to predict the objectives
    objectives = model.predict(np.array([features]))[0]
    
    return tuple(objectives)  # Return objectives as a tuple

toolbox.register("evaluate", evaluate)

# Configure NSGA-II parameters
MU = 100  # Number of individuals in each generation
LAMBDA = 120  # Number of offspring to produce in each generation
CXPB = 0.7  # Probability of mating two individuals
MUTPB = 0.2  # Probability of mutating an individual
NGEN = 1000  # Number of generations

# Create the initial population
pop = toolbox.population(n=MU)

# Run the NSGA-II algorithm
algorithms.eaMuPlusLambda(pop, toolbox, MU, LAMBDA, CXPB, MUTPB, NGEN)

# Extract the non-dominated fronts
fronts = tools.sortNondominated(pop, len(pop), first_front_only=False)

# Extract solutions from each front (including all fronts)
optimal_solutions = [front[:] for front in fronts]

# Extract corresponding variables (X) and objectives (Y) for each front
X_optimal_solutions = [np.array([ind for ind in front]) for front in optimal_solutions]
Y_optimal_solutions = [np.array([evaluate(ind) for ind in front]) for front in optimal_solutions]

# Save the fronts of ranks 0 and 1 along with their corresponding variables
np.savez("optimal_solutions.npz", 
         front0_variables=X_optimal_solutions[0], 
         front0_objectives=Y_optimal_solutions[0], 
         front1_variables=X_optimal_solutions[1], 
         front1_objectives=Y_optimal_solutions[1])

# %%
y_prediction[9999]

# %%
X_scaled[9999]

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Define the model architecture
model = keras.Sequential()

# Add four hidden layers, each with 60 nodes and hyperbolic tangent activation function.
model.add(layers.Dense(40, activation='tanh', input_shape=(28,)))
model.add(layers.Dense(40, activation='tanh'))
model.add(layers.Dense(40, activation='tanh'))
model.add(layers.Dense(40, activation='tanh'))
# Add the output layer with 7 nodes (one for each objective)
model.add(layers.Dense(7))
# Add the output layer with 7 nodes (one for each objective)

# Compile the model with Adam optimizer and appropriate learning rate
optimizer = keras.optimizers.Adam(learning_rate=0.001, beta_1=0.99, beta_2=0.999)
model.compile(optimizer=optimizer, loss='mean_squared_error')

#Train the model for 10,000 epochs with a batch size of 500 points
hist1= model.fit(X_train, y_train, epochs=1000, batch_size=100, validation_data=(X_test, y_test), shuffle = 'true',verbose = 'false')

# %%
epoch1 = hist1.epoch
val_loss1 = hist1.history['val_loss']
train_loss1 = hist1.history['loss']

# %%
#Train the model for 10,000 epochs with a batch size of 500 points
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Define the model architecture
model = keras.Sequential()

# Add four hidden layers, each with 60 nodes and hyperbolic tangent activation function.
model.add(layers.Dense(40, activation='tanh', input_shape=(28,)))
model.add(layers.Dense(40, activation='tanh'))
model.add(layers.Dense(40, activation='tanh'))
model.add(layers.Dense(40, activation='tanh'))
# Add the output layer with 7 nodes (one for each objective)
model.add(layers.Dense(7))
# Add the output layer with 7 nodes (one for each objective)

# Compile the model with Adam optimizer and appropriate learning rate
optimizer = keras.optimizers.Adam(learning_rate=0.001, beta_1=0.99, beta_2=0.999)
model.compile(optimizer=optimizer, loss='mean_squared_error')

#Train the model for 10,000 epochs with a batch size of 500 points
hist2= model.fit(X_train, y_train, epochs=1000, batch_size=250, validation_data=(X_test, y_test), shuffle = 'true',verbose = 'false')
epoch2 = hist2.epoch
val_loss2 = hist2.history['val_loss']
train_loss2 = hist2.history['loss']

# %%
#Train the model for 10,000 epochs with a batch size of 500 points
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Define the model architecture
model = keras.Sequential()

# Add four hidden layers, each with 60 nodes and hyperbolic tangent activation function.
model.add(layers.Dense(40, activation='tanh', input_shape=(28,)))
model.add(layers.Dense(40, activation='tanh'))
model.add(layers.Dense(40, activation='tanh'))
model.add(layers.Dense(40, activation='tanh'))
# Add the output layer with 7 nodes (one for each objective)
model.add(layers.Dense(7))
# Add the output layer with 7 nodes (one for each objective)

# Compile the model with Adam optimizer and appropriate learning rate
optimizer = keras.optimizers.Adam(learning_rate=0.001, beta_1=0.99, beta_2=0.999)
model.compile(optimizer=optimizer, loss='mean_squared_error')

#Train the model for 10,000 epochs with a batch size of 500 points
hist3= model.fit(X_train, y_train, epochs=1000, batch_size=500, validation_data=(X_test, y_test), shuffle = 'true',verbose = 'false')
epoch3 = hist3.epoch
val_loss3 = hist3.history['val_loss']
train_loss3 = hist3.history['loss']

# %%
plt.figure(figsize=(10,8))
plt.subplot(1,2,1)
plt.plot(epoch1, train_loss1, label ='100')
plt.plot(epoch2, train_loss2, label ='250')
plt.plot(epoch3, train_loss3, label ='500')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('training  loss')
plt.title('training  loss vs epoch for different batch sizes')
plt.tight_layout()
plt.subplot(1,2,2)
plt.plot(epoch1, val_loss1, label ='100')
plt.plot(epoch2, val_loss2, label ='250')
plt.plot(epoch3, val_loss3, label ='500')
plt.xlabel('epoch')
plt.ylabel('validation  loss')
plt.title('validation  loss vs epoch for different batch sizes')
plt.legend()
plt.tight_layout()
plt.show
plt.savefig('lossvsepoch2.png')
#from google.colab import files
#files.download( "lossvsepoch2.png" )

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers


# Define the model architecture
model = keras.Sequential()

# Add four hidden layers, each with 60 nodes and hyperbolic tangent activation function.
# Add four hidden layers, each with 60 nodes and hyperbolic tangent activation function.
model.add(layers.Dense(60, activation='tanh', input_shape=(28,)))
model.add(layers.Dense(60, activation='tanh'))
model.add(layers.Dense(60, activation='tanh'))
model.add(layers.Dense(60, activation='tanh'))

# Add the output layer with 7 nodes (one for each objective)
model.add(layers.Dense(7))

# Compile the model with Adam optimizer and appropriate learning rate
optimizer = keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)
model.compile(optimizer=optimizer, loss='mean_squared_error')


# Train the model for 10,000 epochs with a batch size of 500 poin

hist5= model.fit(X_train, y_train, epochs=500, batch_size=500, validation_data=(X_test, y_test), shuffle = 'true',verbose = 'false')

# %%
epoch5 = hist5.epoch
val_loss5 = hist5.history['val_loss']
train_loss5 = hist5.history['loss']
#print(epoch, val_loss1)

# %%
plt.figure(figsize=(10,8))
plt.subplot(1,2,1)
plt.plot(epoch4, train_loss4, label ='250')
plt.plot(epoch5, train_loss5, label ='500')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('training  loss')
plt.title('training  loss vs epoch for different batch sizes')
plt.tight_layout()
plt.subplot(1,2,2)
plt.plot(epoch4, val_loss4, label ='250')
plt.plot(epoch5, val_loss5, label ='500')
plt.xlabel('epoch')
plt.ylabel('validation  loss')
plt.title('validation  loss vs epoch for different batch sizes')
plt.legend()
plt.tight_layout()
plt.show
plt.savefig('lossvsepoch21.png')
#from google.colab import files
#files.download( "lossvsepoch2.png" )

# %%
y_pred = model.predict(x=X_test)
row,col= y_pred.shape
print(row, col)
y_pred

# %%
# Assuming 'y_pred_scaled' contains the scaled predictions from the neural network
#X_original = scaler.inverse_transform(X_scaled)
# To get back to the original data from the scaled data
#x_original = scaler_x.inverse_transform(x_scaled)
#y_original = scaler_y.inverse_transform(y_scaled)
y_pred_original_scale =scaler_y.inverse_transform(y_pred)
y_test_original_scale = scaler_y.inverse_transform(y_test)

# %%
y_pred_original_scale.shape

# %%
import seaborn as sns
row,col= y_pred_original_scale.shape
print(row, col)
plt.figure(figsize=(15,15))
ind =int(np.sqrt(col))+1
for i in range(0,col):
    plt.subplot(ind,ind,i+1)
    plt.hexbin(y_test_original_scale [:,i], y_pred_original_scale [:,i], cmap='Reds') #supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 
    #'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r',
    #'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', '
    #PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn',
    #'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 
    #'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 
    #'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'winter', 'winter_r'
    plt.ylabel('predicted outputs')
    plt.xlabel('actual outputs')
    plt.tight_layout()
plt.show()
residuals= (y_pred_original_scale - y_test_original_scale)
rsq = np.sum(residuals**2, axis =0)/(np.sum(y_test_original_scale**2, axis=0))
print(rsq)

# %%
import seaborn as sns
plt.figure(figsize=(5,5))
plt.plot(y_test_original_scale [:,0]*1e+7, y_pred_original_scale [:,0]*1e+7, '.r')      
plt.ylabel('$\epsilon_{n,x}$(test) (mm-mrad)')
plt.xlabel('$\epsilon_{n,x}$(predicted) (mm-mrad)')
plt.tight_layout()
plt.show()
#residuals= (y_pred_original_scale[:,0]- y_test_original_scale[:,0])
#rsq = np.sum(residuals**2, axis =0)/(np.sum(y_test_original_scale**2, axis=0))
#print(rsq)

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(10, 10))  # Adjust the figure size as needed
# First subplot
plt.subplot(3, 3, 1)
plt.plot(y_test_original_scale [:,0]*1e+6, y_pred_original_scale [:,0]*1e+6, '.r')      
plt.ylabel('$\epsilon_{n,x}$(test) (mm-mrad)')
plt.xlabel('$\epsilon_{n,x}$(predicted) (mm-mrad)')
#plt.title('Subplot 1')
# Second subplot
plt.subplot(3, 3, 2)
plt.plot(y_test_original_scale [:,1]*1e+6, y_pred_original_scale [:,1]*1e+6, '.b')      
plt.ylabel('$\epsilon_{n,y}$(test) (mm-mrad)')
plt.xlabel('$\epsilon_{n,y}$(predicted) (mm-mrad)')
# Third subplot
plt.subplot(3, 3, 3)
plt.plot(y_test_original_scale [:,2]*1e+12, y_pred_original_scale [:,2]*1e+12, '.g')      
plt.ylabel('$\sigma_z$(test) (ps)')
plt.xlabel('$\sigma_z$ (predicted) (ps)')
#plt.title('Subplot 3')
# Fourth subplot
plt.subplot(3, 3, 4)
plt.plot(y_test_original_scale [:,3]*1e+2, y_pred_original_scale [:,3]*1e+2, '.r')      
plt.ylabel('beam-loss (mm-mrad)')
plt.xlabel('beam-loss (predicted) (mm-mrad)')
#plt.title('Subplot 4')
# Fifth subplot
plt.subplot(3, 3, 5)
plt.plot(y_test_original_scale [:,4]*1e+3, y_pred_original_scale [:,4]*1e+3, '.g')      
plt.ylabel('$\sigma_{x}$(test) (mm)')
plt.xlabel('$\sigma_x$(predicted) (mm)')
#plt.title('Subplot 5')
# Sixth subplot
plt.subplot(3, 3, 6)
plt.plot(y_test_original_scale [:,5]*1e+3, y_pred_original_scale [:,5]*1e+3, '.b')      
plt.ylabel('$\sigma_{y}$(test) (mm)')
plt.xlabel('$\sigma_y$(predicted) (mm)')
#plt.title('Subplot 6')
# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.plot(y_test_original_scale [:,6]/(7*1e+6), y_pred_original_scale [:,6]/(7*1e+6), '.g')      
plt.ylabel('$\sigma_{E_k}$(test) ')
plt.xlabel('$\sigma_{E_k}$(predicted)')
#plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Assuming y_test_original_scale and y_pred_original_scale are your data arrays

# Define the linear function for LSQ fit (y = mx + b)
def linear_fit(x, m, b):
    return m * x + b

# Perform the LSQ fit
popt, _ = curve_fit(linear_fit, y_test_original_scale[:, 6] / 7000000, y_pred_original_scale[:, 6] / 7000000)

# Extract the fit coefficients
m, b = popt

# Generate the predicted values using the LSQ fit
y_fit = linear_fit(y_test_original_scale[:, 6] / 7000000, m, b)

# Create a figure
plt.figure(figsize=(5, 4))

# Plot the original data
plt.plot(y_test_original_scale[:, 6] / 7000000, y_pred_original_scale[:, 6] / 7000000, '.g', label='Data')

# Plot the LSQ fit line
plt.plot(y_test_original_scale[:, 6] / 7000000, y_fit, 'r-', label='LSQ Fit')

# Add labels and legend
plt.ylabel('$\sigma_{E_k}$(test)')
plt.xlabel('$\sigma_{E_k}$(predicted)')
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Assuming y_test_original_scale and y_pred_original_scale are your data arrays

# Define the linear function for LSQ fit (y = mx + b)
def linear_fit(x, m, b):
    return m * x + b

# Perform the LSQ fit
popt, _ = curve_fit(linear_fit, y_test_original_scale[:, 6] / 7000000, y_pred_original_scale[:, 6] / 7000000)

# Extract the fit coefficients
m, b = popt

# Generate the predicted values using the LSQ fit
y_fit = linear_fit(y_test_original_scale[:, 6] / 7000000, m, b)

# Create a figure
plt.figure(figsize=(5, 4))

# Plot the original data with a scatter plot
plt.scatter(y_test_original_scale[:, 6] / 7000000, y_pred_original_scale[:, 6] / 7000000, c='g', label='Data', marker='.')

# Plot the LSQ fit line with a bold, large line
plt.plot(y_test_original_scale[:, 6] / 7000000, y_fit, 'r-', linewidth=3, label='LSQ Fit')

# Add labels and legend
plt.ylabel('$\sigma_{E_k}$(test)')
plt.xlabel('$\sigma_{E_k}$(predicted)')
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt  # Import for plotting

# Define the model architecture
model = keras.Sequential()

# Add four hidden layers, each with 60 nodes and hyperbolic tangent activation function.
model.add(layers.Dense(40, activation='tanh', input_shape=(28,)))
model.add(layers.Dense(40, activation='tanh'))
model.add(layers.Dense(40, activation='tanh'))
model.add(layers.Dense(40, activation='tanh'))
# Add the output layer with 7 nodes (one for each objective)
model.add(layers.Dense(7))

# Compile the model with Adam optimizer and appropriate learning rate
optimizer = keras.optimizers.Adam(learning_rate=0.001, beta_1=0.99, beta_2=0.999)
model.compile(optimizer=optimizer, loss='mean_squared_error')

# Create empty lists to store MSE loss values
train_losses = []

# Train the model for 1000 epochs with a batch size of 100 points
for epoch in range(1000):
    history = model.fit(X_train, y_train, epochs=1, batch_size=100, validation_data=(X_test, y_test), shuffle=True, verbose=0)
    
    # Calculate and append MSE loss to the list
    mse_loss = history.history['loss'][0]
    train_losses.append(mse_loss)

# Plot the MSE loss vs. number of training examples seen
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(train_losses) + 1), train_losses, color='blue')
plt.xlabel('Number of Training Examples Seen')
plt.ylabel('MSE Loss')
plt.show()

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# Define the model architecture
model = keras.Sequential()

# Add four hidden layers, each with 60 nodes and hyperbolic tangent activation function.
model.add(layers.Dense(40, activation='tanh', input_shape=(28,)))
model.add(layers.Dense(40, activation='tanh'))
model.add(layers.Dense(40, activation='tanh'))
model.add(layers.Dense(40, activation='tanh'))
# Add the output layer with 7 nodes (one for each objective)
model.add(layers.Dense(7))

# Compile the model with Adam optimizer and appropriate learning rate
optimizer = keras.optimizers.Adam(learning_rate=0.001, beta_1=0.99, beta_2=0.999)
model.compile(optimizer=optimizer, loss='mean_squared_error')

# Create empty lists to store MSE loss values and number of training examples seen
train_losses = []
num_training_examples_seen = []

# Initialize a counter for tracking the number of training examples seen
examples_seen = 0

# Train the model for 1000 epochs with a batch size of 100 points
for epoch in range(1000):
    history = model.fit(X_train, y_train, epochs=1, batch_size=500, validation_data=(X_test, y_test), shuffle=True, verbose=0)
    
    # Get the number of training examples in the current batch
    batch_size = X_train.shape[0]
    
    # Update the counter for the number of training examples seen
    examples_seen += batch_size
    
    # Calculate and append MSE loss to the list
    mse_loss = history.history['loss'][0]
    train_losses.append(mse_loss)
    
    # Append the number of training examples seen to the list
    num_training_examples_seen.append(examples_seen)

# Plot the MSE loss vs. the number of training examples seen
plt.figure(figsize=(8, 6))
plt.plot(num_training_examples_seen, train_losses, color='blue')
plt.xlabel('Number of Training Examples Seen')
plt.xlim(200)
plt.ylabel('MSE Loss')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.plot(num_training_examples_seen, train_losses, color='blue')
plt.xlabel('Number of Training Examples Seen')
plt.xlim([300,500000])
plt.ylabel('MSE Loss')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(10, 10))  # Adjust the figure size as needed
# First subplot
plt.subplot(2, 2, 1)
plt.plot(y_test_original_scale[:,0]*1e+6, y_test_original_scale[:,2]*1e+12, '.r', label='GPT simulation')  
plt.plot(y_pred_original_scale[:,0]*1e+6, y_pred_original_scale[:,2]*1e+12, '.b', label ='NN Prediction')  
plt.xlabel('$\epsilon_{n,x}$ (mm-mrad)')
plt.ylabel('$\sigma_{z}$ (ps)')
plt.legend()
#plt.title('Subplot 1')
# Second subplot
plt.subplot(2, 2, 2)
plt.plot(y_test_original_scale[:,1]*1e+6, y_test_original_scale[:,2]*1e+12, '.r', label='GPT simulation')  
plt.plot(y_pred_original_scale[:,1]*1e+6, y_pred_original_scale[:,2]*1e+12, '.b', label ='NN Prediction')  
plt.xlabel('$\epsilon_{n,y}$ (mm-mrad)')
plt.ylabel('$\sigma_{z}$ (ps)')
plt.legend()
# Fifth subplot
plt.subplot(2, 2, 3)
plt.plot(y_test_original_scale[:,6]/7000000, y_test_original_scale[:,4]*1e+3, '.g', label='GPT simulation')  
plt.plot(y_pred_original_scale[:,6]/7000000, y_pred_original_scale[:,4]*1e+3, '.m', label ='NN Prediction')     
plt.xlabel('$\sigma_{\mathrm{E_k}}$ (ps)')
plt.ylabel('$\sigma_x$( (mm)')
plt.legend()
#plt.title('Subplot 5')
# Sixth subplot
plt.subplot(2, 2, 4)
plt.plot(y_test_original_scale[:,2]*1e+12, y_test_original_scale[:,4]*1000, '.r', label='GPT simulation')  
plt.plot(y_pred_original_scale[:,2]*1e+12, y_pred_original_scale[:,4]*1000, '.b', label ='NN Prediction')  
plt.ylabel('$\sigma_{x}$ (mm)')
plt.xlabel('$\sigma_{z}$ (ps)')
plt.legend()
#plt.title('Subplot 6')
# Adjust spacing between subplots
#plt.tight_layout()

# Show the plot
plt.show()

# %%
features=X_scaled,
objectives=y_scaled

# %%
y_pred= model.predict(features)

# %%
#column = my_array[:, column_index]
plt.figure(figsize=(5,5))
plt.scatter(y_val_original_scale[:,0]*1e6, y_pred_original_scale[:,0]*1e6, label='norm xemittance')
plt.ylabel('predicted outputs')
plt.xlabel('actual outputs')
plt.legend()
 #plt.tight_layout()
plt.show()
#residuals= (y_pred -y_val)
#rsq = np.sum(residuals**2, axis =0)/(np.sum(y_val**2, axis=0))

# %%
plt.figure(figsize=(10,10))
ind =int(np.sqrt(col))+1
for i in range(0,col):
 plt.subplot(ind,ind,i+1)
 plt.scatter(y_val_original_scale[:,i], y_pred_original_scale[:,i])
 plt.ylabel('predicted outputs')
 plt.xlabel('actual outputs')
 #plt.tight_layout()
plt.savefig('simvsprediction.png')
from google.colab import files
files.download( "simvsprediction.png" )
plt.show()
residuals= (y_pred -y_val)
rsq = np.sum(residuals**2, axis =0)/(np.sum(y_val**2, axis=0))
print(rsq)

# %%
#column = my_array[:, column_index]
plt.figure(figsize=(5,5))
plt.scatter(y_val_original_scale[:,1]*1e6, y_pred_original_scale[:,1]*1e6, label='norm emittance')
plt.ylabel('predicted outputs')
plt.xlabel('actual outputs')
plt.legend()
 #plt.tight_layout()
plt.show()
#residuals= (y_pred -y_val)
#rsq = np.sum(residuals**2, axis =0)/(np.sum(y_val**2, axis=0))

# %%
#column = my_array[:, column_index]
plt.figure(figsize=(5,5))
plt.scatter(y_val_original_scale[:,3]*100, y_pred_original_scale[:,3]*100, label='norm emittance')
plt.ylabel('predicted outputs')
plt.xlabel('actual outputs')
plt.legend()
 #plt.tight_layout()
plt.show()
#residuals= (y_pred -y_val)
#rsq = np.sum(residuals**2, axis =0)/(np.sum(y_val**2, axis=0))

# %%
import random
import numpy as np
from deap import base, creator, tools, algorithms
from tensorflow import keras
from tensorflow.keras import layers

# Define the evaluation function for your objectives using the given neural network
def evaluate_objectives(individual):
    # Split the individual's weights into corresponding layer shapes
    shapes = [w.shape for w in model.get_weights()]
    weights = []
    start = 0

    for shape in shapes:
        size = np.prod(shape)
        weight = individual[start:start+size].reshape(shape)
        weights.append(weight)
        start += size

    model.set_weights(weights)

    # Calculate the predictions for the test dataset
    predictions = model.predict(X_test)

    # Calculate the mean squared error for each objective
    mse_objectives = np.mean((predictions - y_test)**2, axis=0)

    # Return the mean squared error values as a tuple (Objective 1, Objective 2, ..., Objective 7)
    return tuple(mse_objectives)

# Define the number of objectives and their types (minimize or maximize)
num_objectives = 7
creator.create("FitnessMin", base.Fitness, weights=(-1.0,) * num_objectives)

# Define the individual representation and the population type
creator.create("Individual", np.ndarray, fitness=creator.FitnessMin)

# Create a toolbox for evolution
toolbox = base.Toolbox()

# Register the evaluation function and the individual generator
toolbox.register("evaluate", evaluate_objectives)
toolbox.register("individual", tools.initRepeat, creator.Individual, lambda: np.random.uniform(-1, 1), n=sum(np.prod(w.shape) for w in model.get_weights()))
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

# Genetic operators
toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=0.1, indpb=0.1)
toolbox.register("select", tools.selNSGA2)

def main():
    population_size = 100
    num_generations = 50

    population = toolbox.population(n=population_size)

    # Evaluate the initial population
    fitnesses = map(toolbox.evaluate, population)
    for ind, fit in zip(population, fitnesses):
        ind.fitness.values = fit

    # Perform the evolution
    for generation in range(num_generations):
        offspring = algorithms.varAnd(population, toolbox, cxpb=0.5, mutpb=0.1)
        fits = toolbox.map(toolbox.evaluate, offspring)
        for ind, fit in zip(offspring, fits):
            ind.fitness.values = fit

        population = toolbox.select(population + offspring, k=population_size)

    # Extract the Pareto front from the final population
    pareto_front = tools.selBest(population, len(population))

    return pareto_front

if __name__ == "__main__":
    # Replace X_train, y_train, X_test, and y_test with your actual training and test datasets
    pareto_front = main()
    print(pareto_front)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have the Pareto front obtained from your main function
#pareto_front = main()

# Extract the objectives from the Pareto front
objectives = [ind.fitness.values for ind in pareto_front]

# Normalize the objectives (for example, to [0, 1] range)
min_val = np.min(objectives, axis=0)
max_val = np.max(objectives, axis=0)
normalized_objectives = (objectives - min_val) / (max_val - min_val)

# Separate the normalized objectives into individual lists
objective1 = [obj[0] for obj in normalized_objectives]
objective2 = [obj[1] for obj in normalized_objectives]

# Create a scatter plot of the Pareto front
plt.figure(figsize=(8, 6))
plt.scatter(objective1, objective2, c='b', marker='o', label='Pareto Front')
plt.xlabel('Normalized Objective 1')
plt.ylabel('Normalized Objective 2')
plt.title('Pareto Front (Normalized)')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# %%
pareto_front_original_scale = scaler.inverse_transform(pareto_front)

# %%
# Extract the objective values from the Pareto front for Objective 1 and Objective 2
objectives = np.array([ind.fitness.values for ind in pareto_front])
objective1_values = objectives[:, 0]
objective2_values = objectives[:, 2]
obj1= scaler.inverse_transform(objective1_values)
obj2= scaler.inverse_transform(objective2_values)

# Plot the Pareto front for Objective 1 and Objective 2
plt.figure(figsize=(8, 6))
plt.scatter(objective1_values, objective2_values)
plt.xlabel('Objective 1')
plt.ylabel('Objective 2')
plt.title('Pareto Front (Objective 1 vs Objective 2)')
plt.grid()
plt.show()

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import numpy as np
from sklearn.model_selection import train_test_split
split=80
# Step 1: Split data into training and testing sets (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size = (100 - split) / 100.,random_state = 42)
# Step 2: Further split the training set into training and validation sets (75% training, 25% validation)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42)

from tensorflow.keras import layers

# Define the model architecture
model = keras.Sequential()

# Add four hidden layers, each with 40 nodes and hyperbolic tangent activation function.
model.add(layers.Dense(40, activation='tanh', input_shape=(28,)))
model.add(layers.Dense(40, activation='tanh'))
model.add(layers.Dense(40, activation='tanh'))
model.add(layers.Dense(40, activation='tanh'))

# Add the output layer with 7 nodes (one for each objective)
model.add(layers.Dense(7))

# Compile the model with Adam optimizer and appropriate learning rate
optimizer = keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)
model.compile(optimizer=optimizer, loss='mean_squared_error')

#split=80
# Step 1: Split data into training and testing sets (80% training, 20% testing)
#X_train, X_test, X_val, y_train, y_test, y_val = train_test_split(X_scaled, y_scaled, test_size = (100 - split) / 100., val_size=(100 - split) / 100., random_state = 42)
# Step 2: Further split the training set into training and validation sets (75% training, 25% validation)
#X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42)
# Split the data into training, validation, and test sets
# Assuming you have a function or method to split the data into train, val, and test sets
#X_train, X_val, X_test, y_train, y_val, y_test = split_data(X_scaled, y_scaled)

# Train the model for 10,000 epochs with a batch size of 500 points
model.fit(X_train, y_train, epochs=100, batch_size=100, validation_data=(X_val, y_val), shuffle = 'true',verbose = 'false')

# Evaluate the model on the test set
loss1 = model.evaluate(X_train, y_train)
loss2 = model.evaluate(X_test, y_test)
loss3 = model.evaluate(X_val, y_val)
print("Test loss:", loss1, loss2, loss3)

# %%
# Create a MirroredStrategy for data parallelism
strategy = tf.distribute.MirroredStrategy()

# Define and compile your model within the strategy's scope
with strategy.scope():
    # Define the model architecture
    model = keras.Sequential()

    # Add four hidden layers, each with 20 nodes and hyperbolic tangent activation function.
    model.add(layers.Dense(20, activation='tanh', input_shape=(28,)))
    model.add(layers.Dense(20, activation='tanh'))
    model.add(layers.Dense(20, activation='tanh'))
    model.add(layers.Dense(20, activation='tanh'))

    # Add the output layer with 12 nodes (one for each objective)
    model.add(layers.Dense(7))

    # Compile the model with Adam optimizer and appropriate learning rate
    optimizer = keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mean_squared_error')

# Scale the input data to fit within the range of [-1, 1]
def scale_data(df1):
    min_val = np.min(data)
    max_val = np.max(data)
    scaled_data = -1 + 2 * (data - min_val) / (max_val - min_val)
    return scaled_data

X_scaled = scale_data(X)
y_scaled = scale_data(y)

# Split the data into training, validation, and test sets
# Assuming you have a function or method to split the data into train, val, and test sets
#X_train, X_val, X_test, Y_train, Y_val, Y_test = split_data(X_scaled, Y_scaled)

# Train the model for 10,000 epochs with a batch size of 500 points
model.fit(X_train, _train, epochs=10, batch_size=50, validation_data=(X_val, Y_val))

# Evaluate the model on the test set
loss = model.evaluate(X_test, Y_test)
print("Test loss:", loss)

# %%
# !pip install keras-tuner

# %% [markdown]
# **Hyperparameter Tuning: in keras**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import keras_tuner
from keras_tuner.tuners import RandomSearch

# %%
def build_model(hp):
    model = keras.Sequential()
    model.add(layers.Input(shape=((8000,28),)))  # Replace 'input_shape' with the appropriate value
    for i in range(hp.Int('num_layers', 1, 4)):  # Number of layers (1 to 4)
        model.add(layers.Dense(units=hp.Int('units_' + str(i), 32, 256, 32), activation='tanh'))  # Units per layer (32 to 256 in steps of 32)
    model.add(layers.Dense(units=7, activation='softmax'))  # Output layer, replace 'num_classes' with the number of classes in your problem

    # Compile the model
    model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='val_accuracy',  # The metric to optimize (replace with 'val_loss' for loss minimization)
    max_trials=10,  # Total number of trials
    executions_per_trial=2,  # Number of times to train each model (reduces the impact of random initialization)
    directory='my_dir',  # Directory to store the search results
    project_name='my_project'  # Name of the search project
     )

# %%
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier

# Create a function that returns the Keras model
def create_model(optimizer='adam', activation='relu', units=7):
    model = Sequential()
    # Add layers to your model
    # ...
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Wrap the Keras model with KerasClassifier for compatibility with GridSearchCV
keras_model = KerasClassifier(build_fn=create_model, epochs=10, batch_size=32, verbose=0)

# Define hyperparameters to tune
param_grid = {
    'optimizer': ['adam', 'sgd'],
    'activation': ['relu', 'tanh'],
    'units': [32, 64, 128]
}

# Perform grid search
grid_search = GridSearchCV(estimator=keras_model, param_grid=param_grid, cv=3)
grid_result = grid_search.fit(X_train, y_train)

# Print the best hyperparameters and corresponding accuracy
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Input, Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import RandomizedSearchCV
#from scikeras.wrappers import TensorFlowModelWrapper
from sklearn.model_selection import train_test_split

# Step 1: Prepare your multi-input, multi-output (MIMO) Keras model
def create_model(optimizer='adam', activation='relu', units=32):
    model = Sequential()
    model.add(Dense(units, activation=activation, input_shape=(28,)))
    # Add more layers as needed for your model architecture
    # ...
    model.add(Dense(7))  # Output layer with 7 nodes for 7 output objectives
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# Step 2: Define your evaluation function to return a list of loss values for all output objectives
def evaluate_model(model, X, y):
    y_pred = model.predict(X)
    losses = np.mean((y_pred - y)**2, axis=0)  # Compute mean squared error for each output objective
    return losses.tolist()

# Step 3: Prepare your data and use RandomizedSearchCV for hyperparameter tuning
# Assuming you have your input data X and output data y

# Split your data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# Wrap the Keras model with KerasRegressor for compatibility with RandomizedSearchCV
# Wrap the Keras model with TensorFlowModelWrapper for compatibility with RandomizedSearchCV
keras_model = KerasRegressor(build_fn=create_model, epochs=10, batch_size=32, verbose=0)(build_fn=create_model, epochs=10, batch_size=32, verbose=0)

# Define hyperparameter distributions to sample from
param_dist = {
    'optimizer': ['adam', 'sgd'],
    'activation': ['relu', 'tanh'],
    'units': [20, 40]
}

# Perform random search
random_search = RandomizedSearchCV(estimator=keras_model, param_distributions=param_dist, cv=3, n_iter=5)
random_result = random_search.fit(X_train, y_train)

# Print the best hyperparameters and corresponding loss values
print("Best: %f using %s" % (random_result.best_score_, random_result.best_params_))
print("Validation Losses for Best Model:", evaluate_model(random_result.best_estimator_, X_val, y_val))
